# %%
import pandas as pd
import json

# %%
info_names = ["id", "adhoc", "call_id", "cospace", "current_participants", "current_time", "forwarding", "locked", "lync_conferencing", "max_participants", "mean_participants", "recording", "streaming", "time_diff"]

# %%
roster_names = ["id", "active_speaker", "call_id", "connected", "datetime", "endpoint_recording", "initial", "onhold", "presenter", "ringing"]

# %%
info_df = pd.read_csv("info.csv", header=None, names=info_names)

# %%
info_df
# Out:
#                                                     id  adhoc  \
# 0    79ed8466-f432-4aca-b0ff-6246c7de2e172020-06-02...  False
# 1    626fb875-1c90-4cf2-ae70-c99367fe19df2020-06-04...  False
# 2    64c427c8-0516-4126-b0f4-f9ac2ff1b8242020-06-03...  False
# 3    53489d27-6574-45e3-a67c-553ebdb2ce782020-06-03...  False
# 4    df2462dc-423b-4215-bc3f-94f678632f1a2020-06-04...  False
# ..                                                 ...    ...
# 112  6598df6d-2486-4a6b-9be1-f75bb76f0dc72020-06-05...  False
# 113  c8de82a5-cfc3-4f45-9ab8-28cebfeb35d92020-06-05...  False
# 114  eb5948ec-0a85-48dd-8764-b473b2c8362f2020-06-02...  False
# 115  9542a2a6-a542-4734-bf1e-98f68dafcde12020-06-05...  False
# 116  9281033a-4d61-4e93-9cf4-0a197094aafa2020-06-08...  False
#
#                                   call_id  cospace  current_participants  \
# 0    79ed8466-f432-4aca-b0ff-6246c7de2e17     True                     1
# ...

# %%
info_df.sort_values(by="current_time", inplace=True)

# %%
info_df
# Out:
#                                                     id  adhoc  \
# 88   430aa8e9-1d22-425b-9d10-ffa07e7deee72020-06-02...  False
# 65   430aa8e9-1d22-425b-9d10-ffa07e7deee72020-06-02...  False
# 34   bb313699-ceae-439c-967b-c72ce71e4fee2020-06-02...  False
# 17   5f670f70-7142-4dec-a878-1435b4defaf12020-06-02...  False
# 95   b3dbd058-75da-4f85-9285-c1606aa15b3c2020-06-02...  False
# ..                                                 ...    ...
# 37   107ff145-3c39-43dd-becd-c272a6bd28272020-06-09...  False
# 80   f1695b02-5968-4a90-8498-c75ce5217e8e2020-06-09...  False
# 105  69ade151-a198-4bbe-96fa-0bded9feb8872020-06-09...  False
# 10   d9147cb2-ac7d-4e0b-9792-ebb3ead1c4222020-06-09...  False
# 41   c998fbe7-0930-4e44-85a0-7f50391d14262020-06-09...  False
#
#                                   call_id  cospace  current_participants  \
# 88   430aa8e9-1d22-425b-9d10-ffa07e7deee7     True                     0
# ...

# %%
roster_df = pd.read_csv("roster.csv", header=None, names=roster_names)

# %%
roster_df.sort_values(by=["datetime"], inplace=True)

# %%
roster_df
# Out:
#                                                    id  active_speaker  \
# 94  430aa8e9-1d22-425b-9d10-ffa07e7deee72020-06-02...               0
# 90  bb313699-ceae-439c-967b-c72ce71e4fee2020-06-02...               1
# 63  f53615a1-cfa9-45b8-a62d-a1cd15ac606a2020-06-02...               0
# 97  5f670f70-7142-4dec-a878-1435b4defaf12020-06-02...               0
# 58  92c47f0a-071a-4a8a-96e5-84742f8c9ef32020-06-02...               0
# ..                                                ...             ...
# 48  5f757eba-76b0-4fac-b4c5-1f167acc2e642020-06-09...               1
# 22  107ff145-3c39-43dd-becd-c272a6bd28272020-06-09...               1
# 18  f1695b02-5968-4a90-8498-c75ce5217e8e2020-06-09...               0
# 76  d9147cb2-ac7d-4e0b-9792-ebb3ead1c4222020-06-09...               0
# 7   c998fbe7-0930-4e44-85a0-7f50391d14262020-06-09...               1
#
#                                  call_id  connected  \
# 94  430aa8e9-1d22-425b-9d10-ffa07e7deee7          1
# ...
