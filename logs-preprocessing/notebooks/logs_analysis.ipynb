# %%
from pyspark import SparkContext, SparkConf, SQLContext
from pyspark.sql import SparkSession
import json
from os import listdir
from os.path import isfile, join
import platform
import pandas as pd
from itertools import chain

# %%
LOGS_DIR_PATH = "/run/media/jola/DATA/JOLEG/inzynierka/logs" # path to dir with log files (only)
MSG_TYPES = ['callListUpdate', 'rosterUpdate','callInfoUpdate']

# %% [markdown]
# ## Basic functions for logs preprocessing

# %%
def get_absolute_path(log_file):
    paths = {
        "Linux" : LOGS_DIR_PATH + "/" + log_file,
        "Windows" : LOGS_DIR_PATH + "\\" + log_file
    }
    return paths.get(platform.system(), '')

# %%
def transform_msg(message):
    msg = message[0]
    date = message[1]
    msg["date"] = date
    return msg

# %%
def transform_call_list_or_roster_update(msg, date, bridge_num):
    msg_id = msg["messageId"]
    msg_type = msg["type"]
    subscriptionIndex = msg["subscriptionIndex"]
    updates = []
    for update in msg["updates"]:
        update["type"] = msg_type
        update["messageId"] = msg_id
        update["subscriptionIndex"] = subscriptionIndex
        update["date"] = date
        update["bridge_num"] = bridge_num
        updates.append(update)
    return updates

# %%
def transform_call_info(msg, date, bridge_num):
    msg_id = msg["messageId"]
    msg_type = msg["type"]
    subscriptionIndex = msg["subscriptionIndex"]
    call_info = msg["callInfo"]
    call_info["type"] = msg_type
    call_info["messageId"] = msg_id
    call_info["subscriptionIndex"] = subscriptionIndex
    call_info["date"] = date
    call_info["bridge_num"] = bridge_num
    return [call_info]

# %%
def transform(msg, date, bridge_num):
    transformation = {
        "callInfoUpdate" : lambda x: transform_call_info(x, date, bridge_num),
        "rosterUpdate" : lambda x: transform_call_list_or_roster_update(x, date, bridge_num),
        "callListUpdate" : lambda x: transform_call_list_or_roster_update(x, date, bridge_num)
    }
    return transformation[msg["type"]](msg)

# %%
def preprocess_data(data, bridge_num):
    messages = [transform(el["message"], el["date"], bridge_num) for el in data if el["type"] == "message" and el["message"]["type"] in MSG_TYPES]
    return list(chain(*messages))

# %%
def join_all_logs(files):
    all_data = []
    
    for i,log_file in enumerate(files):
        with open(log_file) as f:
            data = json.load(f)
            messages = preprocess_data(data, i)
            all_data.extend(messages)
            print(len(data))
    
    print(len(all_data))
    return all_data

# %% [markdown]
# ## Extract all callListUpdate events and save them to file

# %%
def get_all_events(files):
    all_data = []
    
    for i,log_file in enumerate(files):
        with open(log_file) as f:
            data = json.load(f)
            data = [el for el in data if el["type"] == "message" and el["message"]["type"] == "callListUpdate"]
            all_data.extend(data)
            print(len(data))
    
    print(len(all_data))
    return all_data

# %%
log_files = [get_absolute_path(file) for file in listdir(LOGS_DIR_PATH)]
data = get_all_events(log_files)
# Out:
# 618
# 1004
# 1634
# 1177
# 4433

# %%
data[0].keys()
# Out:
# dict_keys(['type', 'message', 'date'])

# %%
data[0]["message"].keys()
# Out:
# dict_keys(['messageId', 'type', 'subscriptionIndex', 'updates'])

# %%
data[0]["message"]
# Out:
# {'messageId': 3,
#  'type': 'callListUpdate',
#  'subscriptionIndex': 3,
#  'updates': [{'call': '835b808c-eb3d-4b6f-b82b-c312eb86cba0',
#    'updateType': 'add',
#    'callCorrelator': 'ffe3cfd2-deb1-4050-9133-f02e57af45b6',
#    'name': '[PWSZ] Elektryczność i elektronika (GZ-C)',
#    'participants': 0,
#    'distributedInstances': 0,
#    'streaming': 'inactive',
#    'recording': 'active',
#    'endpointRecording': 'inactive',
#    'lockState': 'locked',
#    'callType': 'coSpace'}]}

# %%
data[0]
# Out:
# {'type': 'message',
#  'message': {'messageId': 3,
#   'type': 'callListUpdate',
#   'subscriptionIndex': 3,
#   'updates': [{'call': '835b808c-eb3d-4b6f-b82b-c312eb86cba0',
#     'updateType': 'add',
#     'callCorrelator': 'ffe3cfd2-deb1-4050-9133-f02e57af45b6',
#     'name': '[PWSZ] Elektryczność i elektronika (GZ-C)',
#     'participants': 0,
#     'distributedInstances': 0,
#     'streaming': 'inactive',
#     'recording': 'active',
#     'endpointRecording': 'inactive',
#     'lockState': 'locked',
#     'callType': 'coSpace'}]},
#  'date': '2020-06-02T09:17:55.428965'}

# %%
def write_json(data, filename='data.json'): 
    with open(filename,'w') as f: 
        json.dump(data, f)

# %%
write_json(data, 'calls_data.json')

# %% [markdown]
# ## Load and preprocess all logs data

# %% [markdown]
# ### Load all logs data

# %%
log_files = [get_absolute_path(file) for file in listdir(LOGS_DIR_PATH)]
data = join_all_logs(log_files)
data
# Out:
# 55403
# 52051
# 65893
# 55759
# 49699
# [{'call': '835b808c-eb3d-4b6f-b82b-c312eb86cba0',
#   'updateType': 'add',
#   'callCorrelator': 'ffe3cfd2-deb1-4050-9133-f02e57af45b6',
#   'name': '[PWSZ] Elektryczność i elektronika (GZ-C)',
#   'participants': 0,
#   'distributedInstances': 0,
#   'streaming': 'inactive',
#   'recording': 'active',
#   'endpointRecording': 'inactive',
#   'lockState': 'locked',
#   'callType': 'coSpace',
#   'type': 'callListUpdate',
#   'messageId': 3,
#   'subscriptionIndex': 3,
#   'date': '2020-06-02T09:17:55.428965',
#   'bridge_num': 0},
#  {'participant': '596ffb52-b285-4e55-b812-d718b8021cb4',
#   'updateType': 'add',
#   'name': 'Przemysław Sułek',
#   'uri': 'guest265363688@meet.mche.edu.pl',
#   'state': 'initial',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 6,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:17:55.478968',
#   'bridge_num': 0},
#  {'name': '[PWSZ] Elektryczność i elektronika (GZ-C)',
#   'participants': 0,
#   'streaming': 'inactive',
#   'recording': 'active',
#   'endpointRecording': 'inactive',
#   'joinAudioMuteOverride': None,
#   'lockState': 'locked',
#   'callType': 'coSpace',
#   'callCorrelator': 'ffe3cfd2-deb1-4050-9133-f02e57af45b6',
#   'distributedInstances': 0,
#   'type': 'callInfoUpdate',
#   'messageId': 7,
#   'subscriptionIndex': 2,
#   'date': '2020-06-02T09:17:55.479968',
#   'bridge_num': 0},
#  {'call': '835b808c-eb3d-4b6f-b82b-c312eb86cba0',
#   'updateType': 'update',
#   'distributedInstances': 1,
#   'type': 'callListUpdate',
#   'messageId': 8,
#   'subscriptionIndex': 3,
#   'date': '2020-06-02T09:17:55.553975',
#   'bridge_num': 0},
#  {'distributedInstances': 1,
#   'type': 'callInfoUpdate',
#   'messageId': 9,
#   'subscriptionIndex': 2,
#   'date': '2020-06-02T09:17:55.554973',
#   'bridge_num': 0},
#  {'call': '835b808c-eb3d-4b6f-b82b-c312eb86cba0',
#   'updateType': 'update',
#   'distributedInstances': 2,
#   'type': 'callListUpdate',
#   'messageId': 10,
#   'subscriptionIndex': 3,
#   'date': '2020-06-02T09:17:55.571976',
#   'bridge_num': 0},
#  {'distributedInstances': 2,
#   'type': 'callInfoUpdate',
#   'messageId': 11,
#   'subscriptionIndex': 2,
#   'date': '2020-06-02T09:17:55.572975',
#   'bridge_num': 0},
#  {'call': '835b808c-eb3d-4b6f-b82b-c312eb86cba0',
#   'updateType': 'update',
#   'distributedInstances': 3,
#   'lockState': 'notLocked',
#   'type': 'callListUpdate',
#   'messageId': 12,
#   'subscriptionIndex': 3,
#   'date': '2020-06-02T09:17:55.588977',
#   'bridge_num': 0},
#  {'lockState': 'notLocked',
#   'distributedInstances': 3,
#   'type': 'callInfoUpdate',
#   'messageId': 13,
#   'subscriptionIndex': 2,
#   'date': '2020-06-02T09:17:55.589977',
#   'bridge_num': 0},
#  {'call': '835b808c-eb3d-4b6f-b82b-c312eb86cba0',
#   'updateType': 'update',
#   'participants': 2,
#   'type': 'callListUpdate',
#   'messageId': 14,
#   'subscriptionIndex': 3,
#   'date': '2020-06-02T09:17:55.762990',
#   'bridge_num': 0},
#  {'participant': 'be4da92e-43c7-4400-b801-1e975bce91cb',
#   'updateType': 'add',
#   'name': 's.porebski',
#   'uri': 's.porebski@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 15,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:17:55.763991',
#   'bridge_num': 0},
#  {'participant': '2ce58d89-b582-43fe-b790-3f1800011d4a',
#   'updateType': 'add',
#   'name': 'Mateusz Kącki',
#   'uri': 'guest2973839663@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 15,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:17:55.763991',
#   'bridge_num': 0},
#  {'participants': 2,
#   'type': 'callInfoUpdate',
#   'messageId': 16,
#   'subscriptionIndex': 2,
#   'date': '2020-06-02T09:17:55.764991',
#   'bridge_num': 0},
#  {'call': '835b808c-eb3d-4b6f-b82b-c312eb86cba0',
#   'updateType': 'update',
#   'participants': 3,
#   'type': 'callListUpdate',
#   'messageId': 17,
#   'subscriptionIndex': 3,
#   'date': '2020-06-02T09:17:55.925014',
#   'bridge_num': 0},
#  {'participant': 'ba63969a-2c0e-49a9-9f4b-5fb174e56e6c',
#   'updateType': 'add',
#   'name': 'j.cabaj',
#   'uri': 'j.cabaj@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 18,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:17:55.926011',
#   'bridge_num': 0},
#  {'participant': 'd027781d-5ff9-4a7c-97e5-b4da23e0ccf3',
#   'updateType': 'add',
#   'name': 'Tomasz Cąber',
#   'uri': 'guest68489067@meet.mche.edu.pl',
#   'state': 'initial',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 18,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:17:55.926011',
#   'bridge_num': 0},
#  {'participants': 3,
#   'type': 'callInfoUpdate',
#   'messageId': 19,
#   'subscriptionIndex': 2,
#   'date': '2020-06-02T09:17:55.927009',
#   'bridge_num': 0},
#  {'call': '835b808c-eb3d-4b6f-b82b-c312eb86cba0',
#   'updateType': 'update',
#   'participants': 9,
#   'type': 'callListUpdate',
#   'messageId': 20,
#   'subscriptionIndex': 3,
#   'date': '2020-06-02T09:17:55.961013',
#   'bridge_num': 0},
#  {'participant': '9469b785-70d3-4457-8460-67e15d049901',
#   'updateType': 'add',
#   'name': 'recording',
#   'uri': 'guest3046127548@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 21,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:17:55.963012',
#   'bridge_num': 0},
#  {'participant': '4521dda0-f520-4019-89da-2ec13dbb5199',
#   'updateType': 'add',
#   'name': 'P. Dziedzic',
#   'uri': 'guest2599545232@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 21,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:17:55.963012',
#   'bridge_num': 0},
#  {'participant': '7a268db6-b018-41f4-bafe-5922ce990a3b',
#   'updateType': 'add',
#   'name': 'Jakub Trzósło',
#   'uri': 'guest3004967410@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 21,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:17:55.963012',
#   'bridge_num': 0},
#  {'participant': '045e2394-e39e-4321-b601-620db1b5b1f0',
#   'updateType': 'add',
#   'name': 'g.klesiewicz',
#   'uri': 'g.klesiewicz@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 21,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:17:55.963012',
#   'bridge_num': 0},
#  {'participant': '61b42a11-403c-4fe8-b29b-b74b85831f99',
#   'updateType': 'add',
#   'name': 'd.wiktorowski',
#   'uri': 'd.wiktorowski@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 21,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:17:55.963012',
#   'bridge_num': 0},
#  {'participant': '7bd8b3fa-c8df-4c9f-9ac2-fa2e946590d6',
#   'updateType': 'add',
#   'name': 'k.kolin',
#   'uri': 'k.kolin@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 21,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:17:55.963012',
#   'bridge_num': 0},
#  {'participants': 9,
#   'type': 'callInfoUpdate',
#   'messageId': 22,
#   'subscriptionIndex': 2,
#   'date': '2020-06-02T09:17:55.964013',
#   'bridge_num': 0},
#  {'call': '835b808c-eb3d-4b6f-b82b-c312eb86cba0',
#   'updateType': 'add',
#   'callCorrelator': 'ffe3cfd2-deb1-4050-9133-f02e57af45b6',
#   'name': '[PWSZ] Elektryczność i elektronika (GZ-C)',
#   'participants': 9,
#   'distributedInstances': 3,
#   'streaming': 'inactive',
#   'recording': 'active',
#   'endpointRecording': 'inactive',
#   'lockState': 'notLocked',
#   'callType': 'coSpace',
#   'type': 'callListUpdate',
#   'messageId': 3,
#   'subscriptionIndex': 3,
#   'date': '2020-06-02T09:18:24.821187',
#   'bridge_num': 0},
#  {'participant': '596ffb52-b285-4e55-b812-d718b8021cb4',
#   'updateType': 'add',
#   'name': 'Przemysław Sułek',
#   'uri': 'guest265363688@meet.mche.edu.pl',
#   'state': 'initial',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 6,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:18:24.825187',
#   'bridge_num': 0},
#  {'participant': 'be4da92e-43c7-4400-b801-1e975bce91cb',
#   'updateType': 'add',
#   'name': 's.porebski',
#   'uri': 's.porebski@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 6,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:18:24.825187',
#   'bridge_num': 0},
#  {'participant': '2ce58d89-b582-43fe-b790-3f1800011d4a',
#   'updateType': 'add',
#   'name': 'Mateusz Kącki',
#   'uri': 'guest2973839663@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 6,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:18:24.825187',
#   'bridge_num': 0},
#  {'participant': 'ba63969a-2c0e-49a9-9f4b-5fb174e56e6c',
#   'updateType': 'add',
#   'name': 'j.cabaj',
#   'uri': 'j.cabaj@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 6,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:18:24.825187',
#   'bridge_num': 0},
#  {'participant': 'd027781d-5ff9-4a7c-97e5-b4da23e0ccf3',
#   'updateType': 'add',
#   'name': 'Tomasz Cąber',
#   'uri': 'guest68489067@meet.mche.edu.pl',
#   'state': 'initial',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 6,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:18:24.825187',
#   'bridge_num': 0},
#  {'participant': '9469b785-70d3-4457-8460-67e15d049901',
#   'updateType': 'add',
#   'name': 'recording',
#   'uri': 'guest3046127548@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 6,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:18:24.825187',
#   'bridge_num': 0},
#  {'participant': '4521dda0-f520-4019-89da-2ec13dbb5199',
#   'updateType': 'add',
#   'name': 'P. Dziedzic',
#   'uri': 'guest2599545232@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 6,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:18:24.825187',
#   'bridge_num': 0},
#  {'participant': '7a268db6-b018-41f4-bafe-5922ce990a3b',
#   'updateType': 'add',
#   'name': 'Jakub Trzósło',
#   'uri': 'guest3004967410@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 6,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:18:24.825187',
#   'bridge_num': 0},
#  {'participant': '045e2394-e39e-4321-b601-620db1b5b1f0',
#   'updateType': 'add',
#   'name': 'g.klesiewicz',
#   'uri': 'g.klesiewicz@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 6,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:18:24.825187',
#   'bridge_num': 0},
#  {'participant': '61b42a11-403c-4fe8-b29b-b74b85831f99',
#   'updateType': 'add',
#   'name': 'd.wiktorowski',
#   'uri': 'd.wiktorowski@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 6,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:18:24.825187',
#   'bridge_num': 0},
#  {'name': '[PWSZ] Elektryczność i elektronika (GZ-C)',
#   'participants': 9,
#   'streaming': 'inactive',
#   'recording': 'active',
#   'endpointRecording': 'inactive',
#   'joinAudioMuteOverride': None,
#   'lockState': 'notLocked',
#   'callType': 'coSpace',
#   'callCorrelator': 'ffe3cfd2-deb1-4050-9133-f02e57af45b6',
#   'distributedInstances': 3,
#   'type': 'callInfoUpdate',
#   'messageId': 7,
#   'subscriptionIndex': 2,
#   'date': '2020-06-02T09:18:24.826187',
#   'bridge_num': 0},
#  {'participant': '7bd8b3fa-c8df-4c9f-9ac2-fa2e946590d6',
#   'updateType': 'add',
#   'name': 'k.kolin',
#   'uri': 'k.kolin@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 8,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:18:24.827188',
#   'bridge_num': 0},
#  {'participant': '543d5a60-250c-4ea6-90f1-3ed5d8ceed9f',
#   'updateType': 'add',
#   'name': 'Tomasz Cąber',
#   'uri': 'guest1996510515@meet.mche.edu.pl',
#   'state': 'initial',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 9,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:18:27.432394',
#   'bridge_num': 0},
#  {'participant': '596ffb52-b285-4e55-b812-d718b8021cb4',
#   'updateType': 'remove',
#   'reason': 'timeout',
#   'type': 'rosterUpdate',
#   'messageId': 10,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:18:39.535302',
#   'bridge_num': 0},
#  {'call': '835b808c-eb3d-4b6f-b82b-c312eb86cba0',
#   'updateType': 'remove',
#   'reason': 'allLeft',
#   'type': 'callListUpdate',
#   'messageId': 12,
#   'subscriptionIndex': 3,
#   'date': '2020-06-02T09:18:39.819324',
#   'bridge_num': 0},
#  {'call': '9f41f4f1-2891-42ca-9fe4-b6520a006d62',
#   'updateType': 'add',
#   'callCorrelator': 'ffe3cfd2-deb1-4050-9133-f02e57af45b6',
#   'name': '[PWSZ] Elektryczność i elektronika (GZ-C)',
#   'participants': 0,
#   'distributedInstances': 0,
#   'streaming': 'inactive',
#   'recording': 'active',
#   'endpointRecording': 'inactive',
#   'lockState': 'locked',
#   'callType': 'coSpace',
#   'type': 'callListUpdate',
#   'messageId': 3,
#   'subscriptionIndex': 3,
#   'date': '2020-06-02T09:19:33.054350',
#   'bridge_num': 0},
#  {'participant': '5c48a8a7-b827-4077-b72c-e476c0e6a3ef',
#   'updateType': 'add',
#   'name': 'm.migacz1',
#   'uri': 'm.migacz1@meet.mche.edu.pl',
#   'state': 'initial',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 6,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:19:33.108350',
#   'bridge_num': 0},
#  {'name': '[PWSZ] Elektryczność i elektronika (GZ-C)',
#   'participants': 0,
#   'streaming': 'inactive',
#   'recording': 'active',
#   'endpointRecording': 'inactive',
#   'joinAudioMuteOverride': None,
#   'lockState': 'locked',
#   'callType': 'coSpace',
#   'callCorrelator': 'ffe3cfd2-deb1-4050-9133-f02e57af45b6',
#   'distributedInstances': 0,
#   'type': 'callInfoUpdate',
#   'messageId': 7,
#   'subscriptionIndex': 2,
#   'date': '2020-06-02T09:19:33.108350',
#   'bridge_num': 0},
#  {'call': '9f41f4f1-2891-42ca-9fe4-b6520a006d62',
#   'updateType': 'update',
#   'distributedInstances': 2,
#   'type': 'callListUpdate',
#   'messageId': 8,
#   'subscriptionIndex': 3,
#   'date': '2020-06-02T09:19:33.183356',
#   'bridge_num': 0},
#  {'distributedInstances': 2,
#   'type': 'callInfoUpdate',
#   'messageId': 9,
#   'subscriptionIndex': 2,
#   'date': '2020-06-02T09:19:33.184358',
#   'bridge_num': 0},
#  {'call': '9f41f4f1-2891-42ca-9fe4-b6520a006d62',
#   'updateType': 'update',
#   'distributedInstances': 3,
#   'lockState': 'notLocked',
#   'type': 'callListUpdate',
#   'messageId': 10,
#   'subscriptionIndex': 3,
#   'date': '2020-06-02T09:19:33.214358',
#   'bridge_num': 0},
#  {'lockState': 'notLocked',
#   'distributedInstances': 3,
#   'type': 'callInfoUpdate',
#   'messageId': 11,
#   'subscriptionIndex': 2,
#   'date': '2020-06-02T09:19:33.215370',
#   'bridge_num': 0},
#  {'call': '9f41f4f1-2891-42ca-9fe4-b6520a006d62',
#   'updateType': 'update',
#   'participants': 2,
#   'type': 'callListUpdate',
#   'messageId': 12,
#   'subscriptionIndex': 3,
#   'date': '2020-06-02T09:19:33.630391',
#   'bridge_num': 0},
#  {'participant': 'be4da92e-43c7-4400-b801-1e975bce91cb',
#   'updateType': 'add',
#   'name': 's.porebski',
#   'uri': 's.porebski@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 13,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:19:33.632391',
#   'bridge_num': 0},
#  {'participant': '2ce58d89-b582-43fe-b790-3f1800011d4a',
#   'updateType': 'add',
#   'name': 'Mateusz Kącki',
#   'uri': 'guest2973839663@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 13,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:19:33.632391',
#   'bridge_num': 0},
#  {'participants': 2,
#   'type': 'callInfoUpdate',
#   'messageId': 14,
#   'subscriptionIndex': 2,
#   'date': '2020-06-02T09:19:33.633401',
#   'bridge_num': 0},
#  {'call': '9f41f4f1-2891-42ca-9fe4-b6520a006d62',
#   'updateType': 'update',
#   'participants': 3,
#   'type': 'callListUpdate',
#   'messageId': 15,
#   'subscriptionIndex': 3,
#   'date': '2020-06-02T09:19:33.661393',
#   'bridge_num': 0},
#  {'participant': 'ba63969a-2c0e-49a9-9f4b-5fb174e56e6c',
#   'updateType': 'add',
#   'name': 'j.cabaj',
#   'uri': 'j.cabaj@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 16,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:19:33.662393',
#   'bridge_num': 0},
#  {'participant': 'd027781d-5ff9-4a7c-97e5-b4da23e0ccf3',
#   'updateType': 'add',
#   'name': 'Tomasz Cąber',
#   'uri': 'guest68489067@meet.mche.edu.pl',
#   'state': 'initial',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 16,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:19:33.662393',
#   'bridge_num': 0},
#  {'participants': 3,
#   'type': 'callInfoUpdate',
#   'messageId': 17,
#   'subscriptionIndex': 2,
#   'date': '2020-06-02T09:19:33.663393',
#   'bridge_num': 0},
#  {'call': '9f41f4f1-2891-42ca-9fe4-b6520a006d62',
#   'updateType': 'update',
#   'participants': 8,
#   'type': 'callListUpdate',
#   'messageId': 18,
#   'subscriptionIndex': 3,
#   'date': '2020-06-02T09:19:33.674396',
#   'bridge_num': 0},
#  {'participant': '9469b785-70d3-4457-8460-67e15d049901',
#   'updateType': 'add',
#   'name': 'recording',
#   'uri': 'guest3046127548@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 19,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:19:33.675394',
#   'bridge_num': 0},
#  {'participant': '4521dda0-f520-4019-89da-2ec13dbb5199',
#   'updateType': 'add',
#   'name': 'P. Dziedzic',
#   'uri': 'guest2599545232@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 19,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:19:33.675394',
#   'bridge_num': 0},
#  {'participant': '045e2394-e39e-4321-b601-620db1b5b1f0',
#   'updateType': 'add',
#   'name': 'g.klesiewicz',
#   'uri': 'g.klesiewicz@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 19,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:19:33.675394',
#   'bridge_num': 0},
#  {'participant': '61b42a11-403c-4fe8-b29b-b74b85831f99',
#   'updateType': 'add',
#   'name': 'd.wiktorowski',
#   'uri': 'd.wiktorowski@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 19,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:19:33.675394',
#   'bridge_num': 0},
#  {'participant': '7bd8b3fa-c8df-4c9f-9ac2-fa2e946590d6',
#   'updateType': 'add',
#   'name': 'k.kolin',
#   'uri': 'k.kolin@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 19,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:19:33.675394',
#   'bridge_num': 0},
#  {'participant': '543d5a60-250c-4ea6-90f1-3ed5d8ceed9f',
#   'updateType': 'add',
#   'name': 'Tomasz Cąber',
#   'uri': 'guest1996510515@meet.mche.edu.pl',
#   'state': 'initial',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 19,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:19:33.675394',
#   'bridge_num': 0},
#  {'participant': '0cc2a02b-d7c8-4687-a0f2-bb3889a0175d',
#   'updateType': 'add',
#   'name': 'Jakub Trzósło',
#   'uri': 'guest674742874@meet.mche.edu.pl',
#   'state': 'initial',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 19,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:19:33.675394',
#   'bridge_num': 0},
#  {'participants': 8,
#   'type': 'callInfoUpdate',
#   'messageId': 20,
#   'subscriptionIndex': 2,
#   'date': '2020-06-02T09:19:33.678394',
#   'bridge_num': 0},
#  {'call': '9f41f4f1-2891-42ca-9fe4-b6520a006d62',
#   'updateType': 'update',
#   'participants': 9,
#   'type': 'callListUpdate',
#   'messageId': 21,
#   'subscriptionIndex': 3,
#   'date': '2020-06-02T09:19:38.059727',
#   'bridge_num': 0},
#  {'participant': '5c48a8a7-b827-4077-b72c-e476c0e6a3ef',
#   'updateType': 'update',
#   'state': 'connected',
#   'type': 'rosterUpdate',
#   'messageId': 22,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:19:38.061728',
#   'bridge_num': 0},
#  {'participants': 9,
#   'type': 'callInfoUpdate',
#   'messageId': 23,
#   'subscriptionIndex': 2,
#   'date': '2020-06-02T09:19:38.061728',
#   'bridge_num': 0},
#  {'call': '9f41f4f1-2891-42ca-9fe4-b6520a006d62',
#   'updateType': 'update',
#   'participants': 10,
#   'type': 'callListUpdate',
#   'messageId': 24,
#   'subscriptionIndex': 3,
#   'date': '2020-06-02T09:19:38.285751',
#   'bridge_num': 0},
#  {'participant': '0cc2a02b-d7c8-4687-a0f2-bb3889a0175d',
#   'updateType': 'update',
#   'state': 'connected',
#   'type': 'rosterUpdate',
#   'messageId': 25,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:19:38.286743',
#   'bridge_num': 0},
#  {'participants': 10,
#   'type': 'callInfoUpdate',
#   'messageId': 26,
#   'subscriptionIndex': 2,
#   'date': '2020-06-02T09:19:38.286743',
#   'bridge_num': 0},
#  {'participant': '2717c02c-c17f-4579-bc00-004e37b6e256',
#   'updateType': 'add',
#   'name': 'Jakub Musialski',
#   'uri': 'guest302225465@meet.mche.edu.pl',
#   'state': 'initial',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 27,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:19:44.210193',
#   'bridge_num': 0},
#  {'participant': 'd027781d-5ff9-4a7c-97e5-b4da23e0ccf3',
#   'updateType': 'remove',
#   'reason': 'noAnswer',
#   'type': 'rosterUpdate',
#   'messageId': 28,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:19:46.419364',
#   'bridge_num': 0},
#  {'call': '9f41f4f1-2891-42ca-9fe4-b6520a006d62',
#   'updateType': 'add',
#   'callCorrelator': 'ffe3cfd2-deb1-4050-9133-f02e57af45b6',
#   'name': '[PWSZ] Elektryczność i elektronika (GZ-C)',
#   'participants': 10,
#   'distributedInstances': 3,
#   'streaming': 'inactive',
#   'recording': 'active',
#   'endpointRecording': 'inactive',
#   'lockState': 'notLocked',
#   'callType': 'coSpace',
#   'type': 'callListUpdate',
#   'messageId': 3,
#   'subscriptionIndex': 3,
#   'date': '2020-06-02T09:19:49.047563',
#   'bridge_num': 0},
#  {'participant': '5c48a8a7-b827-4077-b72c-e476c0e6a3ef',
#   'updateType': 'add',
#   'name': 'm.migacz1',
#   'uri': 'm.migacz1@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 6,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:19:49.051559',
#   'bridge_num': 0},
#  {'participant': 'ba63969a-2c0e-49a9-9f4b-5fb174e56e6c',
#   'updateType': 'add',
#   'name': 'j.cabaj',
#   'uri': 'j.cabaj@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 6,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:19:49.051559',
#   'bridge_num': 0},
#  {'participant': 'be4da92e-43c7-4400-b801-1e975bce91cb',
#   'updateType': 'add',
#   'name': 's.porebski',
#   'uri': 's.porebski@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 6,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:19:49.051559',
#   'bridge_num': 0},
#  {'participant': '2ce58d89-b582-43fe-b790-3f1800011d4a',
#   'updateType': 'add',
#   'name': 'Mateusz Kącki',
#   'uri': 'guest2973839663@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 6,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:19:49.051559',
#   'bridge_num': 0},
#  {'participant': '9469b785-70d3-4457-8460-67e15d049901',
#   'updateType': 'add',
#   'name': 'recording',
#   'uri': 'guest3046127548@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 6,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:19:49.051559',
#   'bridge_num': 0},
#  {'participant': '4521dda0-f520-4019-89da-2ec13dbb5199',
#   'updateType': 'add',
#   'name': 'P. Dziedzic',
#   'uri': 'guest2599545232@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 6,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:19:49.051559',
#   'bridge_num': 0},
#  {'participant': '045e2394-e39e-4321-b601-620db1b5b1f0',
#   'updateType': 'add',
#   'name': 'g.klesiewicz',
#   'uri': 'g.klesiewicz@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 6,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:19:49.051559',
#   'bridge_num': 0},
#  {'participant': '61b42a11-403c-4fe8-b29b-b74b85831f99',
#   'updateType': 'add',
#   'name': 'd.wiktorowski',
#   'uri': 'd.wiktorowski@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 6,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:19:49.051559',
#   'bridge_num': 0},
#  {'participant': '7bd8b3fa-c8df-4c9f-9ac2-fa2e946590d6',
#   'updateType': 'add',
#   'name': 'k.kolin',
#   'uri': 'k.kolin@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 6,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:19:49.051559',
#   'bridge_num': 0},
#  {'participant': '543d5a60-250c-4ea6-90f1-3ed5d8ceed9f',
#   'updateType': 'add',
#   'name': 'Tomasz Cąber',
#   'uri': 'guest1996510515@meet.mche.edu.pl',
#   'state': 'initial',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 6,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:19:49.051559',
#   'bridge_num': 0},
#  {'name': '[PWSZ] Elektryczność i elektronika (GZ-C)',
#   'participants': 10,
#   'streaming': 'inactive',
#   'recording': 'active',
#   'endpointRecording': 'inactive',
#   'joinAudioMuteOverride': None,
#   'lockState': 'notLocked',
#   'callType': 'coSpace',
#   'callCorrelator': 'ffe3cfd2-deb1-4050-9133-f02e57af45b6',
#   'distributedInstances': 3,
#   'type': 'callInfoUpdate',
#   'messageId': 7,
#   'subscriptionIndex': 2,
#   'date': '2020-06-02T09:19:49.052558',
#   'bridge_num': 0},
#  {'participant': '0cc2a02b-d7c8-4687-a0f2-bb3889a0175d',
#   'updateType': 'add',
#   'name': 'Jakub Trzósło',
#   'uri': 'guest674742874@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 8,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:19:49.053561',
#   'bridge_num': 0},
#  {'participant': '2717c02c-c17f-4579-bc00-004e37b6e256',
#   'updateType': 'add',
#   'name': 'Jakub Musialski',
#   'uri': 'guest302225465@meet.mche.edu.pl',
#   'state': 'initial',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 8,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:19:49.053561',
#   'bridge_num': 0},
#  {'participant': 'f1799fd4-c4e8-4d05-9eaa-d2de6af55bfc',
#   'updateType': 'add',
#   'name': 'j.adamowicz1',
#   'uri': 'j.adamowicz1@meet.mche.edu.pl',
#   'state': 'initial',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 9,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:19:57.335184',
#   'bridge_num': 0},
#  {'call': '9f41f4f1-2891-42ca-9fe4-b6520a006d62',
#   'updateType': 'update',
#   'participants': 11,
#   'type': 'callListUpdate',
#   'messageId': 10,
#   'subscriptionIndex': 3,
#   'date': '2020-06-02T09:19:58.519274',
#   'bridge_num': 0},
#  {'participant': 'f1799fd4-c4e8-4d05-9eaa-d2de6af55bfc',
#   'updateType': 'update',
#   'state': 'connected',
#   'type': 'rosterUpdate',
#   'messageId': 11,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:19:58.521275',
#   'bridge_num': 0},
#  {'participants': 11,
#   'type': 'callInfoUpdate',
#   'messageId': 12,
#   'subscriptionIndex': 2,
#   'date': '2020-06-02T09:19:58.521275',
#   'bridge_num': 0},
#  {'call': '9f41f4f1-2891-42ca-9fe4-b6520a006d62',
#   'updateType': 'update',
#   'participants': 12,
#   'type': 'callListUpdate',
#   'messageId': 13,
#   'subscriptionIndex': 3,
#   'date': '2020-06-02T09:20:05.448804',
#   'bridge_num': 0},
#  {'participant': '2717c02c-c17f-4579-bc00-004e37b6e256',
#   'updateType': 'update',
#   'state': 'connected',
#   'type': 'rosterUpdate',
#   'messageId': 14,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:20:05.449811',
#   'bridge_num': 0},
#  {'participants': 12,
#   'type': 'callInfoUpdate',
#   'messageId': 15,
#   'subscriptionIndex': 2,
#   'date': '2020-06-02T09:20:05.450803',
#   'bridge_num': 0},
#  {'participant': '73915818-7a3a-4e78-9f5a-cd5f8fe26197',
#   'updateType': 'add',
#   'name': 'Tomasz Cąber',
#   'uri': 'guest1499173232@meet.mche.edu.pl',
#   'state': 'initial',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 16,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:20:22.244070',
#   'bridge_num': 0},
#  {'call': '9f41f4f1-2891-42ca-9fe4-b6520a006d62',
#   'updateType': 'add',
#   'callCorrelator': 'ffe3cfd2-deb1-4050-9133-f02e57af45b6',
#   'name': '[PWSZ] Elektryczność i elektronika (GZ-C)',
#   'participants': 12,
#   'distributedInstances': 3,
#   'streaming': 'inactive',
#   'recording': 'active',
#   'endpointRecording': 'inactive',
#   'lockState': 'notLocked',
#   'callType': 'coSpace',
#   'type': 'callListUpdate',
#   'messageId': 3,
#   'subscriptionIndex': 3,
#   'date': '2020-06-02T09:20:31.147748',
#   'bridge_num': 0},
#  {'participant': '5c48a8a7-b827-4077-b72c-e476c0e6a3ef',
#   'updateType': 'add',
#   'name': 'm.migacz1',
#   'uri': 'm.migacz1@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 6,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:20:31.152749',
#   'bridge_num': 0},
#  {'participant': 'ba63969a-2c0e-49a9-9f4b-5fb174e56e6c',
#   'updateType': 'add',
#   'name': 'j.cabaj',
#   'uri': 'j.cabaj@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 6,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:20:31.152749',
#   'bridge_num': 0},
#  {'participant': 'be4da92e-43c7-4400-b801-1e975bce91cb',
#   'updateType': 'add',
#   'name': 's.porebski',
#   'uri': 's.porebski@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 6,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:20:31.152749',
#   'bridge_num': 0},
#  {'participant': '2ce58d89-b582-43fe-b790-3f1800011d4a',
#   'updateType': 'add',
#   'name': 'Mateusz Kącki',
#   'uri': 'guest2973839663@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 6,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:20:31.152749',
#   'bridge_num': 0},
#  {'participant': '9469b785-70d3-4457-8460-67e15d049901',
#   'updateType': 'add',
#   'name': 'recording',
#   'uri': 'guest3046127548@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 6,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:20:31.152749',
#   'bridge_num': 0},
#  {'participant': '4521dda0-f520-4019-89da-2ec13dbb5199',
#   'updateType': 'add',
#   'name': 'P. Dziedzic',
#   'uri': 'guest2599545232@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 6,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:20:31.152749',
#   'bridge_num': 0},
#  {'participant': '045e2394-e39e-4321-b601-620db1b5b1f0',
#   'updateType': 'add',
#   'name': 'g.klesiewicz',
#   'uri': 'g.klesiewicz@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 6,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:20:31.152749',
#   'bridge_num': 0},
#  {'participant': '61b42a11-403c-4fe8-b29b-b74b85831f99',
#   'updateType': 'add',
#   'name': 'd.wiktorowski',
#   'uri': 'd.wiktorowski@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 6,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:20:31.152749',
#   'bridge_num': 0},
#  {'participant': '7bd8b3fa-c8df-4c9f-9ac2-fa2e946590d6',
#   'updateType': 'add',
#   'name': 'k.kolin',
#   'uri': 'k.kolin@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 6,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:20:31.152749',
#   'bridge_num': 0},
#  {'participant': '543d5a60-250c-4ea6-90f1-3ed5d8ceed9f',
#   'updateType': 'add',
#   'name': 'Tomasz Cąber',
#   'uri': 'guest1996510515@meet.mche.edu.pl',
#   'state': 'initial',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 6,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:20:31.152749',
#   'bridge_num': 0},
#  {'name': '[PWSZ] Elektryczność i elektronika (GZ-C)',
#   'participants': 12,
#   'streaming': 'inactive',
#   'recording': 'active',
#   'endpointRecording': 'inactive',
#   'joinAudioMuteOverride': None,
#   'lockState': 'notLocked',
#   'callType': 'coSpace',
#   'callCorrelator': 'ffe3cfd2-deb1-4050-9133-f02e57af45b6',
#   'distributedInstances': 3,
#   'type': 'callInfoUpdate',
#   'messageId': 7,
#   'subscriptionIndex': 2,
#   'date': '2020-06-02T09:20:31.153768',
#   'bridge_num': 0},
#  {'participant': '0cc2a02b-d7c8-4687-a0f2-bb3889a0175d',
#   'updateType': 'add',
#   'name': 'Jakub Trzósło',
#   'uri': 'guest674742874@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 8,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:20:31.154751',
#   'bridge_num': 0},
#  {'participant': '2717c02c-c17f-4579-bc00-004e37b6e256',
#   'updateType': 'add',
#   'name': 'Jakub Musialski',
#   'uri': 'guest302225465@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 8,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:20:31.154751',
#   'bridge_num': 0},
#  {'participant': 'f1799fd4-c4e8-4d05-9eaa-d2de6af55bfc',
#   'updateType': 'add',
#   'name': 'j.adamowicz1',
#   'uri': 'j.adamowicz1@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 8,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:20:31.154751',
#   'bridge_num': 0},
#  {'participant': '73915818-7a3a-4e78-9f5a-cd5f8fe26197',
#   'updateType': 'add',
#   'name': 'Tomasz Cąber',
#   'uri': 'guest1499173232@meet.mche.edu.pl',
#   'state': 'initial',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 8,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:20:31.154751',
#   'bridge_num': 0},
#  {'participant': 'd9620bd4-c88f-4a00-bd01-fd502253719e',
#   'updateType': 'add',
#   'name': '',
#   'uri': '1234',
#   'state': 'initial',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 9,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:20:32.164823',
#   'bridge_num': 0},
#  {'call': '9f41f4f1-2891-42ca-9fe4-b6520a006d62',
#   'updateType': 'update',
#   'participants': 11,
#   'type': 'callListUpdate',
#   'messageId': 10,
#   'subscriptionIndex': 3,
#   'date': '2020-06-02T09:20:32.296832',
#   'bridge_num': 0},
#  {'participant': '0cc2a02b-d7c8-4687-a0f2-bb3889a0175d',
#   'updateType': 'remove',
#   'reason': 'timeout',
#   'type': 'rosterUpdate',
#   'messageId': 11,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:20:32.298836',
#   'bridge_num': 0},
#  {'participant': 'd9620bd4-c88f-4a00-bd01-fd502253719e',
#   'updateType': 'remove',
#   'reason': 'notFound',
#   'type': 'rosterUpdate',
#   'messageId': 11,
#   'subscriptionIndex': 1,
#   'date': '2020-06-02T09:20:32.298836',
#   'bridge_num': 0},
#  {'participants': 11,
#   'type': 'callInfoUpdate',
#   'messageId': 12,
#   'subscriptionIndex': 2,
#   'date': '2020-06-02T09:20:32.298836',
#   'bridge_num': 0},
#  {'call': '9f41f4f1-2891-42ca-9fe4-b6520a006d62',
#   'updateType': 'update',
#   'participants': 12,
#   'type': 'callListUpdate',
#   'messageId': 13,
#   'subscriptionIndex': 3,
#   'date': '2020-06-02T09:20:39.283360',
#   'bridge_num': 0},
#  {'participant': '194200db-781c-4184-87c7-3e81c0dd5b70',
#   'updateType': 'add',
#   'name': '',
#   'uri': 'p.kapustka@mche.edu.pl;x-cisco-number=12137',
#   'state': 'connected',
# ...
#   'date': '2020-06-04T08:12:07.124542',
#   'bridge_num': 0},
#  {'participant': '2e8638f3-2d42-478e-b118-9977a219e94f',
#   'updateType': 'update',
#   'activeSpeaker': True,
#   'type': 'rosterUpdate',
#   'messageId': 13,
#   'subscriptionIndex': 1,
#   'date': '2020-06-04T08:12:08.143613',
#   'bridge_num': 0},
#  {'call': 'f23e34a9-ef3e-4c64-9f69-ec864717097e',
#   'updateType': 'add',
#   'callCorrelator': '9aa2ac9b-0201-40c8-bc2d-007f529dc57d',
#   'name': '[UJ] Geografia (GZ-B)',
#   'participants': 2,
#   'distributedInstances': 0,
#   'streaming': 'inactive',
#   'recording': 'active',
#   'endpointRecording': 'inactive',
#   'lockState': 'notLocked',
#   'callType': 'coSpace',
#   'type': 'callListUpdate',
#   'messageId': 3,
#   'subscriptionIndex': 3,
#   'date': '2020-06-04T08:12:18.672345',
#   'bridge_num': 0},
#  {'call': '73d89b9e-f3ad-48a8-9ffb-28861ba8ca0c',
#   'updateType': 'add',
#   'callCorrelator': 'a549915b-a8bd-45e7-92ec-fcfb1ec45a06',
#   'name': '[PK] Budownictwo (GZ-B)',
#   'participants': 3,
#   'distributedInstances': 2,
#   'streaming': 'active',
#   'recording': 'active',
#   'endpointRecording': 'inactive',
#   'lockState': 'notLocked',
#   'callType': 'coSpace',
#   'type': 'callListUpdate',
#   'messageId': 3,
#   'subscriptionIndex': 3,
#   'date': '2020-06-04T08:12:18.672345',
#   'bridge_num': 0},
#  {'participant': '2e8638f3-2d42-478e-b118-9977a219e94f',
#   'updateType': 'add',
#   'name': 'pk-bud-krak-s',
#   'uri': 'pk-bud-krak-s@mche.edu.pl;x-cisco-number=18591',
#   'state': 'connected',
#   'direction': 'incoming',
#   'canMove': True,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': True,
#   'presenter': True,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 6,
#   'subscriptionIndex': 1,
#   'date': '2020-06-04T08:12:18.676345',
#   'bridge_num': 0},
#  {'participant': '0c041a54-d9e5-492c-af27-484e2bb8a425',
#   'updateType': 'add',
#   'name': 'recording',
#   'uri': 'guest2432775197@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 6,
#   'subscriptionIndex': 1,
#   'date': '2020-06-04T08:12:18.676345',
#   'bridge_num': 0},
#  {'participant': '73865645-661d-4d7a-825a-87882e94cc04',
#   'updateType': 'add',
#   'name': 'streaming',
#   'uri': 'guest2590830604@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 6,
#   'subscriptionIndex': 1,
#   'date': '2020-06-04T08:12:18.676345',
#   'bridge_num': 0},
#  {'name': '[PK] Budownictwo (GZ-B)',
#   'participants': 3,
#   'streaming': 'active',
#   'recording': 'active',
#   'endpointRecording': 'inactive',
#   'joinAudioMuteOverride': None,
#   'lockState': 'notLocked',
#   'callType': 'coSpace',
#   'callCorrelator': 'a549915b-a8bd-45e7-92ec-fcfb1ec45a06',
#   'distributedInstances': 2,
#   'type': 'callInfoUpdate',
#   'messageId': 7,
#   'subscriptionIndex': 2,
#   'date': '2020-06-04T08:12:18.677346',
#   'bridge_num': 0},
#  {'participant': '2e8638f3-2d42-478e-b118-9977a219e94f',
#   'updateType': 'update',
#   'activeSpeaker': False,
#   'type': 'rosterUpdate',
#   'messageId': 8,
#   'subscriptionIndex': 1,
#   'date': '2020-06-04T08:12:26.173871',
#   'bridge_num': 0},
#  {'participant': '2e8638f3-2d42-478e-b118-9977a219e94f',
#   'updateType': 'update',
#   'activeSpeaker': True,
#   'type': 'rosterUpdate',
#   'messageId': 9,
#   'subscriptionIndex': 1,
#   'date': '2020-06-04T08:12:27.166945',
#   'bridge_num': 0},
#  {'participant': '2e8638f3-2d42-478e-b118-9977a219e94f',
#   'updateType': 'update',
#   'activeSpeaker': False,
#   'type': 'rosterUpdate',
#   'messageId': 10,
#   'subscriptionIndex': 1,
#   'date': '2020-06-04T08:12:53.198770',
#   'bridge_num': 0},
#  {'participant': '2e8638f3-2d42-478e-b118-9977a219e94f',
#   'updateType': 'update',
#   'activeSpeaker': True,
#   'type': 'rosterUpdate',
#   'messageId': 11,
#   'subscriptionIndex': 1,
#   'date': '2020-06-04T08:12:54.201841',
#   'bridge_num': 0},
#  {'call': 'f23e34a9-ef3e-4c64-9f69-ec864717097e',
#   'updateType': 'add',
#   'callCorrelator': '9aa2ac9b-0201-40c8-bc2d-007f529dc57d',
#   'name': '[UJ] Geografia (GZ-B)',
#   'participants': 2,
#   'distributedInstances': 0,
#   'streaming': 'inactive',
#   'recording': 'active',
#   'endpointRecording': 'inactive',
#   'lockState': 'notLocked',
#   'callType': 'coSpace',
#   'type': 'callListUpdate',
#   'messageId': 3,
#   'subscriptionIndex': 3,
#   'date': '2020-06-04T08:13:00.768297',
#   'bridge_num': 0},
#  {'call': '73d89b9e-f3ad-48a8-9ffb-28861ba8ca0c',
#   'updateType': 'add',
#   'callCorrelator': 'a549915b-a8bd-45e7-92ec-fcfb1ec45a06',
#   'name': '[PK] Budownictwo (GZ-B)',
#   'participants': 3,
#   'distributedInstances': 2,
#   'streaming': 'active',
#   'recording': 'active',
#   'endpointRecording': 'inactive',
#   'lockState': 'notLocked',
#   'callType': 'coSpace',
#   'type': 'callListUpdate',
#   'messageId': 3,
#   'subscriptionIndex': 3,
#   'date': '2020-06-04T08:13:00.768297',
#   'bridge_num': 0},
#  {'participant': '2e8638f3-2d42-478e-b118-9977a219e94f',
#   'updateType': 'add',
#   'name': 'pk-bud-krak-s',
#   'uri': 'pk-bud-krak-s@mche.edu.pl;x-cisco-number=18591',
#   'state': 'connected',
#   'direction': 'incoming',
#   'canMove': True,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': True,
#   'presenter': True,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 6,
#   'subscriptionIndex': 1,
#   'date': '2020-06-04T08:13:00.790300',
#   'bridge_num': 0},
#  {'participant': '0c041a54-d9e5-492c-af27-484e2bb8a425',
#   'updateType': 'add',
#   'name': 'recording',
#   'uri': 'guest2432775197@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 6,
#   'subscriptionIndex': 1,
#   'date': '2020-06-04T08:13:00.790300',
#   'bridge_num': 0},
#  {'participant': '73865645-661d-4d7a-825a-87882e94cc04',
#   'updateType': 'add',
#   'name': 'streaming',
#   'uri': 'guest2590830604@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 6,
#   'subscriptionIndex': 1,
#   'date': '2020-06-04T08:13:00.790300',
#   'bridge_num': 0},
#  {'name': '[PK] Budownictwo (GZ-B)',
#   'participants': 3,
#   'streaming': 'active',
#   'recording': 'active',
#   'endpointRecording': 'inactive',
#   'joinAudioMuteOverride': None,
#   'lockState': 'notLocked',
#   'callType': 'coSpace',
#   'callCorrelator': 'a549915b-a8bd-45e7-92ec-fcfb1ec45a06',
#   'distributedInstances': 2,
#   'type': 'callInfoUpdate',
#   'messageId': 7,
#   'subscriptionIndex': 2,
#   'date': '2020-06-04T08:13:00.790300',
#   'bridge_num': 0},
#  {'participant': '2e8638f3-2d42-478e-b118-9977a219e94f',
#   'updateType': 'update',
#   'activeSpeaker': False,
#   'type': 'rosterUpdate',
#   'messageId': 8,
#   'subscriptionIndex': 1,
#   'date': '2020-06-04T08:13:20.269664',
#   'bridge_num': 0},
#  {'participant': '2e8638f3-2d42-478e-b118-9977a219e94f',
#   'updateType': 'update',
#   'activeSpeaker': True,
#   'type': 'rosterUpdate',
#   'messageId': 9,
#   'subscriptionIndex': 1,
#   'date': '2020-06-04T08:13:21.252734',
#   'bridge_num': 0},
#  {'call': 'f23e34a9-ef3e-4c64-9f69-ec864717097e',
#   'updateType': 'add',
#   'callCorrelator': '9aa2ac9b-0201-40c8-bc2d-007f529dc57d',
#   'name': '[UJ] Geografia (GZ-B)',
#   'participants': 2,
#   'distributedInstances': 0,
#   'streaming': 'inactive',
#   'recording': 'active',
#   'endpointRecording': 'inactive',
#   'lockState': 'notLocked',
#   'callType': 'coSpace',
#   'type': 'callListUpdate',
#   'messageId': 3,
#   'subscriptionIndex': 3,
#   'date': '2020-06-04T08:13:42.867263',
#   'bridge_num': 0},
#  {'call': '73d89b9e-f3ad-48a8-9ffb-28861ba8ca0c',
#   'updateType': 'add',
#   'callCorrelator': 'a549915b-a8bd-45e7-92ec-fcfb1ec45a06',
#   'name': '[PK] Budownictwo (GZ-B)',
#   'participants': 3,
#   'distributedInstances': 2,
#   'streaming': 'active',
#   'recording': 'active',
#   'endpointRecording': 'inactive',
#   'lockState': 'notLocked',
#   'callType': 'coSpace',
#   'type': 'callListUpdate',
#   'messageId': 3,
#   'subscriptionIndex': 3,
#   'date': '2020-06-04T08:13:42.867263',
#   'bridge_num': 0},
#  {'participant': '2e8638f3-2d42-478e-b118-9977a219e94f',
#   'updateType': 'add',
#   'name': 'pk-bud-krak-s',
#   'uri': 'pk-bud-krak-s@mche.edu.pl;x-cisco-number=18591',
#   'state': 'connected',
#   'direction': 'incoming',
#   'canMove': True,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': True,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 6,
#   'subscriptionIndex': 1,
#   'date': '2020-06-04T08:13:42.873249',
#   'bridge_num': 0},
#  {'participant': '0c041a54-d9e5-492c-af27-484e2bb8a425',
#   'updateType': 'add',
#   'name': 'recording',
#   'uri': 'guest2432775197@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 6,
#   'subscriptionIndex': 1,
#   'date': '2020-06-04T08:13:42.873249',
#   'bridge_num': 0},
#  {'participant': '73865645-661d-4d7a-825a-87882e94cc04',
#   'updateType': 'add',
#   'name': 'streaming',
#   'uri': 'guest2590830604@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 6,
#   'subscriptionIndex': 1,
#   'date': '2020-06-04T08:13:42.873249',
#   'bridge_num': 0},
#  {'name': '[PK] Budownictwo (GZ-B)',
#   'participants': 3,
#   'streaming': 'active',
#   'recording': 'active',
#   'endpointRecording': 'inactive',
#   'joinAudioMuteOverride': None,
#   'lockState': 'notLocked',
#   'callType': 'coSpace',
#   'callCorrelator': 'a549915b-a8bd-45e7-92ec-fcfb1ec45a06',
#   'distributedInstances': 2,
#   'type': 'callInfoUpdate',
#   'messageId': 7,
#   'subscriptionIndex': 2,
#   'date': '2020-06-04T08:13:42.874250',
#   'bridge_num': 0},
#  {'participant': '2e8638f3-2d42-478e-b118-9977a219e94f',
#   'updateType': 'update',
#   'activeSpeaker': True,
#   'type': 'rosterUpdate',
#   'messageId': 8,
#   'subscriptionIndex': 1,
#   'date': '2020-06-04T08:13:43.321283',
#   'bridge_num': 0},
#  {'participant': '2e8638f3-2d42-478e-b118-9977a219e94f',
#   'updateType': 'update',
#   'activeSpeaker': False,
#   'type': 'rosterUpdate',
#   'messageId': 9,
#   'subscriptionIndex': 1,
#   'date': '2020-06-04T08:14:08.361055',
#   'bridge_num': 0},
#  {'participant': '2e8638f3-2d42-478e-b118-9977a219e94f',
#   'updateType': 'update',
#   'activeSpeaker': True,
#   'type': 'rosterUpdate',
#   'messageId': 10,
#   'subscriptionIndex': 1,
#   'date': '2020-06-04T08:14:09.364128',
#   'bridge_num': 0},
#  {'call': 'f23e34a9-ef3e-4c64-9f69-ec864717097e',
#   'updateType': 'add',
#   'callCorrelator': '9aa2ac9b-0201-40c8-bc2d-007f529dc57d',
#   'name': '[UJ] Geografia (GZ-B)',
#   'participants': 2,
#   'distributedInstances': 0,
#   'streaming': 'inactive',
#   'recording': 'active',
#   'endpointRecording': 'inactive',
#   'lockState': 'notLocked',
#   'callType': 'coSpace',
#   'type': 'callListUpdate',
#   'messageId': 3,
#   'subscriptionIndex': 3,
#   'date': '2020-06-04T08:14:24.958310',
#   'bridge_num': 0},
#  {'call': '73d89b9e-f3ad-48a8-9ffb-28861ba8ca0c',
#   'updateType': 'add',
#   'callCorrelator': 'a549915b-a8bd-45e7-92ec-fcfb1ec45a06',
#   'name': '[PK] Budownictwo (GZ-B)',
#   'participants': 3,
#   'distributedInstances': 2,
#   'streaming': 'active',
#   'recording': 'active',
#   'endpointRecording': 'inactive',
#   'lockState': 'notLocked',
#   'callType': 'coSpace',
#   'type': 'callListUpdate',
#   'messageId': 3,
#   'subscriptionIndex': 3,
#   'date': '2020-06-04T08:14:24.958310',
#   'bridge_num': 0},
#  {'participant': '2e8638f3-2d42-478e-b118-9977a219e94f',
#   'updateType': 'add',
#   'name': 'pk-bud-krak-s',
#   'uri': 'pk-bud-krak-s@mche.edu.pl;x-cisco-number=18591',
#   'state': 'connected',
#   'direction': 'incoming',
#   'canMove': True,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': True,
#   'presenter': True,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 6,
#   'subscriptionIndex': 1,
#   'date': '2020-06-04T08:14:24.962305',
#   'bridge_num': 0},
#  {'participant': '0c041a54-d9e5-492c-af27-484e2bb8a425',
#   'updateType': 'add',
#   'name': 'recording',
#   'uri': 'guest2432775197@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 6,
#   'subscriptionIndex': 1,
#   'date': '2020-06-04T08:14:24.962305',
#   'bridge_num': 0},
#  {'participant': '73865645-661d-4d7a-825a-87882e94cc04',
#   'updateType': 'add',
#   'name': 'streaming',
#   'uri': 'guest2590830604@meet.mche.edu.pl',
#   'state': 'connected',
#   'direction': 'outgoing',
#   'canMove': False,
#   'audioMuted': False,
#   'videoMuted': False,
#   'importance': None,
#   'layout': 'onePlusFive',
#   'activeSpeaker': False,
#   'presenter': False,
#   'endpointRecording': 'inactive',
#   'type': 'rosterUpdate',
#   'messageId': 6,
#   'subscriptionIndex': 1,
#   'date': '2020-06-04T08:14:24.962305',
#   'bridge_num': 0},
#  {'name': '[PK] Budownictwo (GZ-B)',
#   'participants': 3,
#   'streaming': 'active',
#   'recording': 'active',
#   'endpointRecording': 'inactive',
#   'joinAudioMuteOverride': None,
#   'lockState': 'notLocked',
#   'callType': 'coSpace',
#   'callCorrelator': 'a549915b-a8bd-45e7-92ec-fcfb1ec45a06',
#   'distributedInstances': 2,
#   'type': 'callInfoUpdate',
#   'messageId': 7,
#   'subscriptionIndex': 2,
#   'date': '2020-06-04T08:14:24.963303',
#   'bridge_num': 0},
#  {'participant': '2e8638f3-2d42-478e-b118-9977a219e94f',
#   'updateType': 'update',
#   'activeSpeaker': False,
#   'type': 'rosterUpdate',
#   'messageId': 8,
#   'subscriptionIndex': 1,
#   'date': '2020-06-04T08:14:25.358337',
#   'bridge_num': 0},
#  {'call': 'f23e34a9-ef3e-4c64-9f69-ec864717097e',
#   'updateType': 'remove',
#   'reason': 'allLeft',
#   'type': 'callListUpdate',
#   'messageId': 9,
#   'subscriptionIndex': 3,
#   'date': '2020-06-04T08:14:25.602365',
#   'bridge_num': 0},
#  {'participant': '2e8638f3-2d42-478e-b118-9977a219e94f',
#   'updateType': 'update',
#   'activeSpeaker': True,
#   'type': 'rosterUpdate',
#   'messageId': 10,
#   'subscriptionIndex': 1,
#   'date': '2020-06-04T08:14:26.361411',
#   'bridge_num': 0},
#  {'participant': '2e8638f3-2d42-478e-b118-9977a219e94f',
#   'updateType': 'update',
#   'activeSpeaker': False,
#   'type': 'rosterUpdate',
#   'messageId': 11,
#   'subscriptionIndex': 1,
#   'date': '2020-06-04T08:14:39.382394',
#   'bridge_num': 0},
#  {'participant': '2e8638f3-2d42-478e-b118-9977a219e94f',
#   'updateType': 'update',
#   'activeSpeaker': True,
#   'type': 'rosterUpdate',
#   'messageId': 12,
#   'subscriptionIndex': 1,
#   'date': '2020-06-04T08:14:40.376458',
#   'bridge_num': 0},
#  {'participant': '2e8638f3-2d42-478e-b118-9977a219e94f',
#   'updateType': 'update',
#   'activeSpeaker': False,
#   'type': 'rosterUpdate',
#   'messageId': 13,
#   'subscriptionIndex': 1,
#   'date': '2020-06-04T08:14:44.389771',
#   'bridge_num': 0},
#  ...]

# %% [markdown]
# ### Divide logs based on message type

# %%
df_info = pd.DataFrame([el for el in data if el["type"] == "callInfoUpdate"])
df_list = pd.DataFrame([el for el in data if el["type"] == "callListUpdate"])
df_roster = pd.DataFrame([el for el in data if el["type"] == "rosterUpdate"])

# %% [markdown]
# ### Preprocess callInfoUpdate events

# %%
calls = list(pd.unique(df_list["call"]))

# %%
dfs_calls = []

for call in calls:
    call_data = df_list[df_list["call"] == call].sort_values(by=["date"])[["call", "updateType", "name", "participants", "streaming", "recording", "date", "reason"]]
    call_data["name"] = call_data["name"].fillna(method="ffill")
    dfs_calls.append(call_data)

# %%
dfs_calls[0]
# Out:
#                                    call updateType  \
# 0  835b808c-eb3d-4b6f-b82b-c312eb86cba0        add
# 1  835b808c-eb3d-4b6f-b82b-c312eb86cba0     update
# 2  835b808c-eb3d-4b6f-b82b-c312eb86cba0     update
# 3  835b808c-eb3d-4b6f-b82b-c312eb86cba0     update
# 4  835b808c-eb3d-4b6f-b82b-c312eb86cba0     update
# 5  835b808c-eb3d-4b6f-b82b-c312eb86cba0     update
# 6  835b808c-eb3d-4b6f-b82b-c312eb86cba0     update
# 7  835b808c-eb3d-4b6f-b82b-c312eb86cba0        add
# 8  835b808c-eb3d-4b6f-b82b-c312eb86cba0     remove
#
#                                         name  participants streaming  \
# 0  [PWSZ] Elektryczność i elektronika (GZ-C)           0.0  inactive
# 1  [PWSZ] Elektryczność i elektronika (GZ-C)           NaN       NaN
# 2  [PWSZ] Elektryczność i elektronika (GZ-C)           NaN       NaN
# 3  [PWSZ] Elektryczność i elektronika (GZ-C)           NaN       NaN
# 4  [PWSZ] Elektryczność i elektronika (GZ-C)           2.0       NaN
# 5  [PWSZ] Elektryczność i elektronika (GZ-C)           3.0       NaN
# 6  [PWSZ] Elektryczność i elektronika (GZ-C)           9.0       NaN
# 7  [PWSZ] Elektryczność i elektronika (GZ-C)           9.0  inactive
# 8  [PWSZ] Elektryczność i elektronika (GZ-C)           NaN       NaN
#
#   recording                        date   reason
# 0    active  2020-06-02T09:17:55.428965      NaN
# 1       NaN  2020-06-02T09:17:55.553975      NaN
# 2       NaN  2020-06-02T09:17:55.571976      NaN
# 3       NaN  2020-06-02T09:17:55.588977      NaN
# 4       NaN  2020-06-02T09:17:55.762990      NaN
# 5       NaN  2020-06-02T09:17:55.925014      NaN
# 6       NaN  2020-06-02T09:17:55.961013      NaN
# 7    active  2020-06-02T09:18:24.821187      NaN
# 8       NaN  2020-06-02T09:18:39.819324  allLeft

# %%
dfs_calls[3]
# Out:
#                                     call updateType                     name  \
# 68  626fb875-1c90-4cf2-ae70-c99367fe19df        add  [PK] Budownictwo (GZ-B)
# 69  626fb875-1c90-4cf2-ae70-c99367fe19df     update  [PK] Budownictwo (GZ-B)
# 70  626fb875-1c90-4cf2-ae70-c99367fe19df        add  [PK] Budownictwo (GZ-B)
# 71  626fb875-1c90-4cf2-ae70-c99367fe19df        add  [PK] Budownictwo (GZ-B)
# 72  626fb875-1c90-4cf2-ae70-c99367fe19df        add  [PK] Budownictwo (GZ-B)
# 73  626fb875-1c90-4cf2-ae70-c99367fe19df        add  [PK] Budownictwo (GZ-B)
# 74  626fb875-1c90-4cf2-ae70-c99367fe19df        add  [PK] Budownictwo (GZ-B)
# 75  626fb875-1c90-4cf2-ae70-c99367fe19df        add  [PK] Budownictwo (GZ-B)
# 76  626fb875-1c90-4cf2-ae70-c99367fe19df        add  [PK] Budownictwo (GZ-B)
# 77  626fb875-1c90-4cf2-ae70-c99367fe19df     remove  [PK] Budownictwo (GZ-B)
#
#     participants streaming recording                        date   reason
# 68           1.0  inactive    active  2020-06-04T07:27:44.618918      NaN
# 69           NaN       NaN       NaN  2020-06-04T07:27:44.788930      NaN
# 70           1.0  inactive    active  2020-06-04T07:28:04.009397      NaN
# 71           1.0  inactive    active  2020-06-04T07:28:46.106561      NaN
# 72           1.0  inactive    active  2020-06-04T07:29:28.211744      NaN
# 73           1.0  inactive    active  2020-06-04T07:30:10.312921      NaN
# 74           1.0  inactive    active  2020-06-04T07:30:52.417108      NaN
# 75           1.0  inactive    active  2020-06-04T07:31:34.517293      NaN
# 76           1.0  inactive    active  2020-06-04T07:32:16.618464      NaN
# 77           NaN       NaN       NaN  2020-06-04T07:32:17.462525  allLeft

# %%
all_calls = pd.concat(dfs_calls)
all_calls
# Out:
#                                       call updateType  \
# 0     835b808c-eb3d-4b6f-b82b-c312eb86cba0        add
# 1     835b808c-eb3d-4b6f-b82b-c312eb86cba0     update
# 2     835b808c-eb3d-4b6f-b82b-c312eb86cba0     update
# 3     835b808c-eb3d-4b6f-b82b-c312eb86cba0     update
# 4     835b808c-eb3d-4b6f-b82b-c312eb86cba0     update
# ...                                    ...        ...
# 4591  107ff145-3c39-43dd-becd-c272a6bd2827     update
# 4592  107ff145-3c39-43dd-becd-c272a6bd2827     update
# 4593  107ff145-3c39-43dd-becd-c272a6bd2827        add
# 4594  107ff145-3c39-43dd-becd-c272a6bd2827     update
# 4595  107ff145-3c39-43dd-becd-c272a6bd2827     remove
#
#                                            name  participants streaming  \
# 0     [PWSZ] Elektryczność i elektronika (GZ-C)           0.0  inactive
# 1     [PWSZ] Elektryczność i elektronika (GZ-C)           NaN       NaN
# 2     [PWSZ] Elektryczność i elektronika (GZ-C)           NaN       NaN
# 3     [PWSZ] Elektryczność i elektronika (GZ-C)           NaN       NaN
# 4     [PWSZ] Elektryczność i elektronika (GZ-C)           2.0       NaN
# ...                                         ...           ...       ...
# 4591              Dawid Suder - wirtualny pokój           NaN       NaN
# 4592              Dawid Suder - wirtualny pokój           2.0       NaN
# 4593              Dawid Suder - wirtualny pokój           2.0  inactive
# 4594              Dawid Suder - wirtualny pokój           1.0       NaN
# 4595              Dawid Suder - wirtualny pokój           NaN       NaN
#
#      recording                        date   reason
# 0       active  2020-06-02T09:17:55.428965      NaN
# 1          NaN  2020-06-02T09:17:55.553975      NaN
# 2          NaN  2020-06-02T09:17:55.571976      NaN
# 3          NaN  2020-06-02T09:17:55.588977      NaN
# 4          NaN  2020-06-02T09:17:55.762990      NaN
# ...        ...                         ...      ...
# 4591  inactive  2020-06-09T15:53:11.608802      NaN
# 4592       NaN  2020-06-09T15:53:11.610804      NaN
# 4593  inactive  2020-06-09T15:53:14.897030      NaN
# 4594       NaN  2020-06-09T15:53:19.552363      NaN
# 4595       NaN  2020-06-09T15:53:32.343431  allLeft
#
# [4596 rows x 8 columns]

# %%
all_calls.to_csv("all_calls.csv", index=None)

# %% [markdown]
# ### Preprocess rosterUpdate

# %%
participants = pd.unique(df_roster["participant"])

dfs_roster = []

for p in participants:
    df_part = df_roster[df_roster["participant"] == p].sort_values(by=["date"])[["participant",
                                                                                 "updateType", 
                                                                                 "name", 
                                                                                 "uri", 
                                                                                 "state", 
                                                                                 "direction", 
                                                                                 "movedParticipant", 
                                                                                 "movedParticipantCallBridge", 
                                                                                 "canMove", 
                                                                                 "audioMuted", 
                                                                                 "videoMuted", 
                                                                                 "importance", 
                                                                                 "layout", 
                                                                                 "activeSpeaker", 
                                                                                 "presenter",
                                                                                 "endpointRecording",
                                                                                 "date"]]
    df_part["name"] = df_part["name"].fillna(method="ffill")
    df_part["uri"] = df_part["uri"].fillna(method="ffill")
    dfs_roster.append(df_part)

# %%
dfs_roster[60]
# Out:
#                                participant updateType          name  \
# 2671  7e1dc01e-d859-4ce6-88a0-23cd3f445424        add  mcdn-oswi-p1
# 2685  7e1dc01e-d859-4ce6-88a0-23cd3f445424     update  mcdn-oswi-p1
# 2687  7e1dc01e-d859-4ce6-88a0-23cd3f445424     update  mcdn-oswi-p1
# 2703  7e1dc01e-d859-4ce6-88a0-23cd3f445424        add  mcdn-oswi-p1
# 2729  7e1dc01e-d859-4ce6-88a0-23cd3f445424        add  mcdn-oswi-p1
# ...                                    ...        ...           ...
# 6151  7e1dc01e-d859-4ce6-88a0-23cd3f445424     update  mcdn-oswi-p1
# 6158  7e1dc01e-d859-4ce6-88a0-23cd3f445424     update  mcdn-oswi-p1
# 6162  7e1dc01e-d859-4ce6-88a0-23cd3f445424     update  mcdn-oswi-p1
# 6164  7e1dc01e-d859-4ce6-88a0-23cd3f445424     update
# 6165  7e1dc01e-d859-4ce6-88a0-23cd3f445424     remove
#
#                                                 uri      state direction  \
# 2671  mcdn-oswi-p1@mche.edu.pl;x-cisco-number=18431  connected  incoming
# 2685  mcdn-oswi-p1@mche.edu.pl;x-cisco-number=18431        NaN       NaN
# 2687  mcdn-oswi-p1@mche.edu.pl;x-cisco-number=18431        NaN       NaN
# 2703  mcdn-oswi-p1@mche.edu.pl;x-cisco-number=18431  connected  incoming
# 2729  mcdn-oswi-p1@mche.edu.pl;x-cisco-number=18431  connected  incoming
# ...                                             ...        ...       ...
# 6151  mcdn-oswi-p1@mche.edu.pl;x-cisco-number=18431        NaN       NaN
# 6158  mcdn-oswi-p1@mche.edu.pl;x-cisco-number=18431        NaN       NaN
# 6162  mcdn-oswi-p1@mche.edu.pl;x-cisco-number=18431     onHold       NaN
# 6164  mcdn-oswi-p1@mche.edu.pl;x-cisco-number=18431        NaN       NaN
# 6165  mcdn-oswi-p1@mche.edu.pl;x-cisco-number=18431        NaN       NaN
#
#      movedParticipant movedParticipantCallBridge canMove audioMuted  \
# 2671              NaN                        NaN    True      False
# 2685              NaN                        NaN     NaN        NaN
# 2687              NaN                        NaN     NaN        NaN
# 2703              NaN                        NaN    True      False
# 2729              NaN                        NaN    True      False
# ...               ...                        ...     ...        ...
# 6151              NaN                        NaN     NaN        NaN
# 6158              NaN                        NaN     NaN        NaN
# 6162              NaN                        NaN     NaN        NaN
# 6164              NaN                        NaN     NaN        NaN
# 6165              NaN                        NaN     NaN        NaN
#
#      videoMuted  importance    layout activeSpeaker presenter  \
# 2671      False         NaN  allEqual         False     False
# 2685        NaN         NaN       NaN          True       NaN
# 2687        NaN         NaN       NaN         False       NaN
# 2703      False         NaN  allEqual         False     False
# 2729      False         NaN  allEqual         False     False
# ...         ...         ...       ...           ...       ...
# 6151        NaN         NaN       NaN          True       NaN
# 6158        NaN         NaN       NaN         False       NaN
# 6162        NaN         NaN       NaN           NaN       NaN
# 6164        NaN         NaN       NaN           NaN       NaN
# 6165        NaN         NaN       NaN           NaN       NaN
#
#      endpointRecording                        date
# 2671          inactive  2020-06-08T09:02:36.818768
# 2685               NaN  2020-06-08T09:02:50.550814
# 2687               NaN  2020-06-08T09:02:51.551891
# 2703          inactive  2020-06-08T09:03:18.907962
# 2729          inactive  2020-06-08T09:04:00.999166
# ...                ...                         ...
# 6151               NaN  2020-06-08T10:53:43.724489
# 6158               NaN  2020-06-08T10:53:45.778635
# 6162               NaN  2020-06-08T10:53:46.587691
# 6164               NaN  2020-06-08T10:53:46.664705
# 6165               NaN  2020-06-08T10:53:46.667701
#
# [373 rows x 17 columns]

# %%
df_list[(df_list["date"]>"2020-06-02T09:17:20.002731")&(df_list["date"]<"2020-06-02T09:17:27.002731")]
# Out:
#                                       call updateType  \
# 3536  2abbb064-9e7d-4c67-9217-2fd2d43de646        add
#
#                             callCorrelator  \
# 3536  ffe3cfd2-deb1-4050-9133-f02e57af45b6
#
#                                            name  participants  \
# 3536  [PWSZ] Elektryczność i elektronika (GZ-C)           8.0
#
#       distributedInstances streaming recording endpointRecording  lockState  \
# 3536                   2.0  inactive    active          inactive  notLocked
#
#      callType            type  messageId  subscriptionIndex  \
# 3536  coSpace  callListUpdate          3                  3
#
#                             date  bridge_num reason
# 3536  2020-06-02T09:17:23.947581           3    NaN

# %%
meeting = df_list[df_list["call"]=="2abbb064-9e7d-4c67-9217-2fd2d43de646"].sort_values(by=["date"])

# %%
pd.unique(meeting["participants"])
# Out:
# array([ 3.,  4.,  5.,  6.,  7.,  8.,  9., nan, 10., 11., 12., 13., 14.,
#        15.])

# %%
all_participants = pd.concat(dfs_roster)
all_participants
# Out:
#                                 participant updateType              name  \
# 0      596ffb52-b285-4e55-b812-d718b8021cb4        add  Przemysław Sułek
# 7756   596ffb52-b285-4e55-b812-d718b8021cb4        add  Przemysław Sułek
# 31237  596ffb52-b285-4e55-b812-d718b8021cb4        add  Przemysław Sułek
# 16303  596ffb52-b285-4e55-b812-d718b8021cb4        add  Przemysław Sułek
# 31248  596ffb52-b285-4e55-b812-d718b8021cb4        add  Przemysław Sułek
# ...                                     ...        ...               ...
# 40792  7b275709-1ce2-4ac9-8fca-a5105fa315a1        add
# 40797  7b275709-1ce2-4ac9-8fca-a5105fa315a1        add
# 40808  7b275709-1ce2-4ac9-8fca-a5105fa315a1        add
# 40816  7b275709-1ce2-4ac9-8fca-a5105fa315a1        add
# 40832  7b275709-1ce2-4ac9-8fca-a5105fa315a1        add
#
#                                    uri      state direction  \
# 0      guest265363688@meet.mche.edu.pl    initial  outgoing
# 7756   guest265363688@meet.mche.edu.pl    initial  outgoing
# 31237  guest265363688@meet.mche.edu.pl    initial  outgoing
# 16303  guest265363688@meet.mche.edu.pl    initial  outgoing
# 31248  guest265363688@meet.mche.edu.pl    initial  outgoing
# ...                                ...        ...       ...
# 40792  mik.sondej@free.calls.webex.com  connected  outgoing
# 40797  mik.sondej@free.calls.webex.com  connected  outgoing
# 40808  mik.sondej@free.calls.webex.com  connected  outgoing
# 40816  mik.sondej@free.calls.webex.com  connected  outgoing
# 40832  mik.sondej@free.calls.webex.com  connected  outgoing
#
#                            movedParticipant  \
# 0                                       NaN
# 7756                                    NaN
# 31237                                   NaN
# 16303                                   NaN
# 31248                                   NaN
# ...                                     ...
# 40792  e0bfff2a-ee7f-0000-3e81-8a9cca550000
# 40797  e0bfff2a-ee7f-0000-3e81-8a9cca550000
# 40808  e0bfff2a-ee7f-0000-3e81-8a9cca550000
# 40816  e0bfff2a-ee7f-0000-3e81-8a9cca550000
# 40832  e0bfff2a-ee7f-0000-3e81-8a9cca550000
#
#                  movedParticipantCallBridge canMove audioMuted videoMuted  \
# 0                                       NaN   False      False      False
# 7756                                    NaN   False      False      False
# 31237                                   NaN   False      False      False
# 16303                                   NaN   False      False      False
# 31248                                   NaN   False      False      False
# ...                                     ...     ...        ...        ...
# 40792  ab000000-0000-0000-2070-43aeca550000    True      False      False
# 40797  ab000000-0000-0000-2070-43aeca550000    True      False      False
# 40808  ab000000-0000-0000-2070-43aeca550000    True      False      False
# 40816  ab000000-0000-0000-2070-43aeca550000    True      False      False
# 40832  ab000000-0000-0000-2070-43aeca550000    True      False      False
#
#        importance       layout activeSpeaker presenter endpointRecording  \
# 0             NaN  onePlusFive         False     False          inactive
# 7756          NaN  onePlusFive         False     False          inactive
# 31237         NaN  onePlusFive         False     False          inactive
# 16303         NaN  onePlusFive         False     False          inactive
# 31248         NaN  onePlusFive         False     False          inactive
# ...           ...          ...           ...       ...               ...
# 40792         NaN     allEqual         False     False          inactive
# 40797         NaN     allEqual         False     False          inactive
# 40808         NaN     allEqual         False     False          inactive
# 40816         NaN     allEqual         False     False          inactive
# 40832         NaN     allEqual         False     False          inactive
#
#                              date
# 0      2020-06-02T09:17:55.478968
# 7756   2020-06-02T09:17:59.659284
# 31237  2020-06-02T09:17:59.659284
# 16303  2020-06-02T09:17:59.662285
# 31248  2020-06-02T09:18:06.044766
# ...                           ...
# 40792  2020-06-09T15:50:26.487893
# 40797  2020-06-09T15:51:08.600038
# 40808  2020-06-09T15:51:50.711127
# 40816  2020-06-09T15:52:32.811078
# 40832  2020-06-09T15:53:14.901030
#
# [40837 rows x 17 columns]

# %%
all_participants.to_csv("all_participants.csv", index=None)

# %% [markdown]
# ### Add call id to callInfoUpdate events

# %% [markdown]
# #### Create dataframe with call id, name, start date and end date -> joined

# %%
df_info.sort_values(by=["date"], inplace=True)

# %%
df_info["name"] = df_info["name"].fillna(method="ffill")

# %%
df_names = df_list[["call", "name", "date"]]

# %%
df_first = df_names.drop_duplicates(subset=["call"], keep="first")

# %%
df_last = df_names.drop_duplicates(subset=["call"], keep="last")

# %%
df_first.reset_index(inplace=True)

# %%
df_last.reset_index(inplace=True)

# %%
df_first.drop(columns=["index"], inplace=True)
# Out:
# /home/jola/.local/lib/python3.8/site-packages/pandas/core/frame.py:4162: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df_last.drop(columns=["index"], inplace=True)

# %%
len(df_first)
# Out:
# 113

# %%
len(df_last)
# Out:
# 113

# %%
df_first.head()
# Out:
#                                    call  \
# 0  835b808c-eb3d-4b6f-b82b-c312eb86cba0
# 1  9f41f4f1-2891-42ca-9fe4-b6520a006d62
# 2  1bec1a39-dcc8-4f8c-a7c8-7caadf0d0f8a
# 3  626fb875-1c90-4cf2-ae70-c99367fe19df
# 4  2b620603-11b4-4c76-833e-3ca16ba11222
#
#                                         name                        date
# 0  [PWSZ] Elektryczność i elektronika (GZ-C)  2020-06-02T09:17:55.428965
# 1  [PWSZ] Elektryczność i elektronika (GZ-C)  2020-06-02T09:19:33.054350
# 2  [PWSZ] Elektryczność i elektronika (GZ-C)  2020-06-02T09:33:12.731069
# 3                    [PK] Budownictwo (GZ-B)  2020-06-04T07:27:44.618918
# 4                    [PK] Budownictwo (GZ-B)  2020-06-04T07:33:40.823827

# %%
df_last.head()
# Out:
#                                    call name                        date
# 0  835b808c-eb3d-4b6f-b82b-c312eb86cba0  NaN  2020-06-02T09:18:39.819324
# 1  9f41f4f1-2891-42ca-9fe4-b6520a006d62  NaN  2020-06-02T09:31:40.827068
# 2  1bec1a39-dcc8-4f8c-a7c8-7caadf0d0f8a  NaN  2020-06-02T09:33:41.453239
# 3  626fb875-1c90-4cf2-ae70-c99367fe19df  NaN  2020-06-04T07:32:17.462525
# 4  811246e7-7ae0-4c41-94a0-1e32cb2081a6  NaN  2020-06-04T07:39:47.440768

# %%
df_last
# Out:
#                                      call name                        date
# 0    835b808c-eb3d-4b6f-b82b-c312eb86cba0  NaN  2020-06-02T09:18:39.819324
# 1    9f41f4f1-2891-42ca-9fe4-b6520a006d62  NaN  2020-06-02T09:31:40.827068
# 2    1bec1a39-dcc8-4f8c-a7c8-7caadf0d0f8a  NaN  2020-06-02T09:33:41.453239
# 3    626fb875-1c90-4cf2-ae70-c99367fe19df  NaN  2020-06-04T07:32:17.462525
# 4    811246e7-7ae0-4c41-94a0-1e32cb2081a6  NaN  2020-06-04T07:39:47.440768
# ..                                    ...  ...                         ...
# 108  aa525af3-0afe-4f76-9e8a-18f43e1f92dd  NaN  2020-06-08T10:12:26.806780
# 109  fc211f14-6b31-422a-be1b-838a70ebd43e  NaN  2020-06-08T12:07:49.113392
# 110  910c095f-1212-41aa-9239-c0ffc906e84a  NaN  2020-06-08T12:08:13.390225
# 111  43c7b9dc-51bb-426a-b538-ff4a25b0eb71  NaN  2020-06-09T08:38:06.582230
# 112  107ff145-3c39-43dd-becd-c272a6bd2827  NaN  2020-06-09T15:53:32.343431
#
# [113 rows x 3 columns]

# %%
joined = df_first.merge(df_last, on="call", how="left")

# %%
joined.drop(columns=["name_y"], inplace=True)

# %%
joined.rename(columns={"name_x": "name", "date_x": "start_date", "date_y": "end_date"}, inplace=True)

# %% [markdown]
# #### Merge joined with df_info and add columns with date -> merged

# %%
df_info.reset_index(inplace=True)

# %%
df_info
# Out:
#       index                                       name  participants  \
# 0      1564         Łukasz Czekierda - wirtualny pokój           0.0
# 1      1565         Łukasz Czekierda - wirtualny pokój           1.0
# 2      1566         Łukasz Czekierda - wirtualny pokój           NaN
# 3       587  [PWSZ] Elektryczność i elektronika (GZ-B)           0.0
# 4       588  [PWSZ] Elektryczność i elektronika (GZ-B)           1.0
# ...     ...                                        ...           ...
# 4261   3132           Bartosz Kwolek - wirtualny pokój           4.0
# 4262   3133           Bartosz Kwolek - wirtualny pokój           3.0
# 4263   3134           Bartosz Kwolek - wirtualny pokój           2.0
# 4264   3135           Bartosz Kwolek - wirtualny pokój           1.0
# 4265   3136           Bartosz Kwolek - wirtualny pokój           1.0
#
#      streaming recording endpointRecording  joinAudioMuteOverride  lockState  \
# 0     inactive  inactive          inactive                    NaN     locked
# 1          NaN       NaN               NaN                    NaN        NaN
# 2          NaN       NaN               NaN                    NaN  notLocked
# 3     inactive    active          inactive                    NaN  notLocked
# 4          NaN       NaN               NaN                    NaN        NaN
# ...        ...       ...               ...                    ...        ...
# 4261       NaN       NaN               NaN                    NaN        NaN
# 4262       NaN       NaN               NaN                    NaN        NaN
# 4263       NaN       NaN               NaN                    NaN        NaN
# 4264       NaN       NaN               NaN                    NaN        NaN
# 4265  inactive  inactive          inactive                    NaN  notLocked
#
#      callType                        callCorrelator  distributedInstances  \
# 0     coSpace  bea1a8ad-9e26-48f6-842e-6f2545864347                   0.0
# 1         NaN                                   NaN                   NaN
# 2         NaN                                   NaN                   NaN
# 3     coSpace  a59b6967-ee91-4f85-b47c-b190ea95b0c8                   0.0
# 4         NaN                                   NaN                   NaN
# ...       ...                                   ...                   ...
# 4261      NaN                                   NaN                   NaN
# 4262      NaN                                   NaN                   NaN
# 4263      NaN                                   NaN                   NaN
# 4264      NaN                                   NaN                   NaN
# 4265  coSpace  c9704788-2d1b-4788-9f21-9ded9fede6d1                   0.0
#
#                 type  messageId  subscriptionIndex  \
# 0     callInfoUpdate          7                  2
# 1     callInfoUpdate         10                  2
# 2     callInfoUpdate         12                  2
# 3     callInfoUpdate          7                  2
# 4     callInfoUpdate         11                  2
# ...              ...        ...                ...
# 4261  callInfoUpdate         26                  2
# 4262  callInfoUpdate         30                  2
# 4263  callInfoUpdate         35                  2
# 4264  callInfoUpdate         39                  2
# 4265  callInfoUpdate          7                  2
#
#                             date  bridge_num
# 0     2020-06-02T00:42:47.985183           2
# 1     2020-06-02T00:42:48.286209           2
# 2     2020-06-02T00:42:48.322213           2
# 3     2020-06-02T07:14:15.263637           1
# 4     2020-06-02T07:14:16.083694           1
# ...                          ...         ...
# 4261  2020-06-09T18:26:54.982966           2
# 4262  2020-06-09T18:26:57.668168           2
# 4263  2020-06-09T18:27:00.432352           2
# 4264  2020-06-09T18:27:01.044394           2
# 4265  2020-06-09T18:27:07.498850           2
#
# [4266 rows x 16 columns]

# %%
merged = df_info.merge(joined, on="name", how="left")

# %%
from datetime import datetime

# %%
merged["start_date"]
# Out:
# 0        2020-06-02T00:42:47.922179
# 1        2020-06-09T16:50:09.980352
# 2        2020-06-02T00:42:47.922179
# 3        2020-06-09T16:50:09.980352
# 4        2020-06-02T00:42:47.922179
#                     ...
# 22735    2020-06-09T16:50:09.588321
# 22736    2020-06-09T16:49:15.169233
# 22737    2020-06-09T16:50:09.588321
# 22738    2020-06-09T16:49:15.169233
# 22739    2020-06-09T16:50:09.588321
# Name: start_date, Length: 22740, dtype: object

# %%
pattern = '%Y-%m-%dT%H:%M:%S.%f'
merged["start_date_con"] = merged["start_date"].apply(lambda x: datetime.strptime(x, pattern))
merged["end_date_con"] = merged["end_date"].apply(lambda x: datetime.strptime(x, pattern))
merged["date_con"] = merged["date"].apply(lambda x: datetime.strptime(x, pattern))

# %%
merged["start_diff"] = abs(merged["date_con"] - merged["start_date_con"])

# %%
merged["end_diff"] = abs(merged["end_date_con"] - merged["date_con"])

# %%
merged["diff"] = merged.apply(lambda x: min(x["end_diff"], x["start_diff"]), axis=1)

# %%
merged.head()
# Out:
#    index                                name  participants streaming  \
# 0   1564  Łukasz Czekierda - wirtualny pokój           0.0  inactive
# 1   1564  Łukasz Czekierda - wirtualny pokój           0.0  inactive
# 2   1565  Łukasz Czekierda - wirtualny pokój           1.0       NaN
# 3   1565  Łukasz Czekierda - wirtualny pokój           1.0       NaN
# 4   1566  Łukasz Czekierda - wirtualny pokój           NaN       NaN
#
#   recording endpointRecording  joinAudioMuteOverride  lockState callType  \
# 0  inactive          inactive                    NaN     locked  coSpace
# 1  inactive          inactive                    NaN     locked  coSpace
# 2       NaN               NaN                    NaN        NaN      NaN
# 3       NaN               NaN                    NaN        NaN      NaN
# 4       NaN               NaN                    NaN  notLocked      NaN
#
#                          callCorrelator  ...  bridge_num  \
# 0  bea1a8ad-9e26-48f6-842e-6f2545864347  ...           2
# 1  bea1a8ad-9e26-48f6-842e-6f2545864347  ...           2
# 2                                   NaN  ...           2
# 3                                   NaN  ...           2
# 4                                   NaN  ...           2
#
#                                    call                  start_date  \
# 0  430aa8e9-1d22-425b-9d10-ffa07e7deee7  2020-06-02T00:42:47.922179
# 1  69ade151-a198-4bbe-96fa-0bded9feb887  2020-06-09T16:50:09.980352
# 2  430aa8e9-1d22-425b-9d10-ffa07e7deee7  2020-06-02T00:42:47.922179
# 3  69ade151-a198-4bbe-96fa-0bded9feb887  2020-06-09T16:50:09.980352
# 4  430aa8e9-1d22-425b-9d10-ffa07e7deee7  2020-06-02T00:42:47.922179
#
#                      end_date             start_date_con  \
# 0  2020-06-02T00:42:58.848011 2020-06-02 00:42:47.922179
# 1  2020-06-09T16:50:10.152364 2020-06-09 16:50:09.980352
# 2  2020-06-02T00:42:58.848011 2020-06-02 00:42:47.922179
# 3  2020-06-09T16:50:10.152364 2020-06-09 16:50:09.980352
# 4  2020-06-02T00:42:58.848011 2020-06-02 00:42:47.922179
#
#                 end_date_con                   date_con  \
# 0 2020-06-02 00:42:58.848011 2020-06-02 00:42:47.985183
# 1 2020-06-09 16:50:10.152364 2020-06-02 00:42:47.985183
# 2 2020-06-02 00:42:58.848011 2020-06-02 00:42:48.286209
# 3 2020-06-09 16:50:10.152364 2020-06-02 00:42:48.286209
# 4 2020-06-02 00:42:58.848011 2020-06-02 00:42:48.322213
#
#               start_diff               end_diff                   diff
# 0 0 days 00:00:00.063004 0 days 00:00:10.862828 0 days 00:00:00.063004
# 1 7 days 16:07:21.995169 7 days 16:07:22.167181 7 days 16:07:21.995169
# 2 0 days 00:00:00.364030 0 days 00:00:10.561802 0 days 00:00:00.364030
# 3 7 days 16:07:21.694143 7 days 16:07:21.866155 7 days 16:07:21.694143
# 4 0 days 00:00:00.400034 0 days 00:00:10.525798 0 days 00:00:00.400034
#
# [5 rows x 25 columns]

# %%
len(df_info)
# Out:
# 4266

# %%
info_preprocessed = merged.loc[merged.groupby('index').diff.idxmin()].reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-61-65c51c6c0b7a> in <module>
# ----> 1 info_preprocessed = merged.loc[merged.groupby('index').diff.idxmin()].reset_index(drop=True)
#
# AttributeError: 'function' object has no attribute 'idxmin'

# %%
len(info_preprocessed)

# %%
info_preprocessed.drop(columns=["index", "start_date", "end_date", "start_date_con", "end_date_con", "date_con", "start_diff", "end_diff", "diff"], inplace=True)

# %%
dict_info_prep = info_preprocessed.to_dict("records")

# %%
dict_info_prep[0]

# %%
def transform_event_info(event):
    final_event = dict()
    final_event["type"] = "message"
    callInfo = {
        "name": event["name"],
        "participants": event["participants"],
        "streaming": event["streaming"],
        "recording": event["recording"],
        "endpointRecording": event["endpointRecording"],
        "joinAudioMuteOverride": event["joinAudioMuteOverride"],
        "lockState": event["lockState"],
        "callType": event["callType"],
        "callCorrelator": event["callCorrelator"],
        "distributedInstances": event["distributedInstances"]
    }
    final_event["message"] = {
        "messageId": 1,
        "type": "callInfoUpdate",
        "subscriptionIndex": 2,
        "callInfo": callInfo
    }
    final_event["date"] = event["date"]
    final_event["call"] = event["call"]
    return final_event

# %%
mapped = list(map(transform_event_info, dict_info_prep))

# %%
write_json(mapped, 'callInfo_data.json')

# %% [markdown]
# ### Add call id to rosterUpdate events

# %%
all_participants.sort_values(by=["date"], inplace=True)

# %%
df_users = all_participants[["participant", "date"]]

# %%
part_first = df_users.drop_duplicates(subset=["participant"], keep="first")

# %%
part_last = df_users.drop_duplicates(subset=["participant"], keep="last")

# %%
joined = part_first.merge(part_last, on="participant", how="left")

# %%
joined.rename(columns={"date_x": "start_date", "date_y": "end_date"}, inplace=True)

# %%
joined

# %%
df_names = df_list[["call", "name", "date"]]

# %%
df_first = df_names.drop_duplicates(subset=["call"], keep="first")

# %%
df_last = df_names.drop_duplicates(subset=["call"], keep="last")

# %%
df_first.reset_index(inplace=True)

# %%
df_last.reset_index(inplace=True)

# %%
joined_calls = df_first.merge(df_last, on="call", how="left")

# %%
joined_calls.drop(columns=["name_y"], inplace=True)

# %%
joined_calls.rename(columns={"name_x": "name", "date_x": "start_date", "date_y": "end_date"}, inplace=True)

# %%
joined_calls.drop(columns=["index_x", "index_y"], inplace=True)

# %%
joined_calls = joined_calls[["call", "start_date", "end_date"]]

# %%
joined["key"] = 1

# %%
joined_calls["key"] = 1

# %%
merged = pd.merge(joined,joined_calls,on='key').drop('key',axis=1)

# %%
merged.rename(columns={"start_date_x":"start_date_p", "end_date_x":"end_date_p", "start_date_y":"start_date_c", "end_date_y":"end_date_c"}, inplace=True)

# %%
merged.columns

# %%
pattern = '%Y-%m-%dT%H:%M:%S.%f'
merged["start_date_p_con"] = merged["start_date_p"].apply(lambda x: datetime.strptime(x, pattern))
merged["end_date_p_con"] = merged["end_date_p"].apply(lambda x: datetime.strptime(x, pattern))
merged["start_date_c_con"] = merged["start_date_c"].apply(lambda x: datetime.strptime(x, pattern))
merged["end_date_c_con"] = merged["end_date_c"].apply(lambda x: datetime.strptime(x, pattern))

# %%
merged["is_between"] = merged.apply(lambda row: row["start_date_p_con"]>=row["start_date_c_con"] and row["end_date_p_con"]<=row["end_date_c_con"], axis=1)

# %%
df_best = merged[merged["is_between"]]

# %%
len(pd.unique(df_best["participant"]))

# %%
len(pd.unique(df_best["participant"])) == len(pd.unique(joined["participant"]))

# %%
rest_participants = [pid for pid in joined["participant"] if pid not in list(df_best["participant"])]

# %%
rest_participants

# %%
counted = df_best.groupby(by=["participant"]).count()

# %%
counted[counted["end_date_p"]>1]

# %%
to_add = merged[merged["participant"].isin(rest_participants)]

# %%
concatenated = pd.concat([df_best, to_add])

# %%
len(concatenated)

# %%
concatenated["start_diff"] = abs(concatenated["start_date_p_con"] - concatenated["start_date_c_con"])

# %%
concatenated["end_diff"] = abs(concatenated["end_date_p_con"] - concatenated["end_date_c_con"])

# %%
concatenated["diff"] = concatenated.apply(lambda x: min(x["end_diff"], x["start_diff"]), axis=1)

# %%
concatenated.head()

# %%
user_preprocessed = concatenated.loc[concatenated.groupby('participant').diff.idxmin()].reset_index(drop=True)

# %%
len(user_preprocessed)

# %%
user_preprocessed["diff"].min()

# %%
maks = user_preprocessed["diff"].max()

# %%
user_preprocessed[user_preprocessed["diff"]==maks]

# %%
participant_call = user_preprocessed[["participant", "call"]]

# %%
final = all_participants.merge(participant_call, how="left", on="participant")

# %%
final.sort_values(by=["date"], inplace=True)

# %%
final.reset_index(drop=True)

# %%
type("a") == str

# %%
def get_value(column, event):
    if not event[column] or (type(event[column])!=str and math.isnan(event[column])):
        return None
    else:
        return event[column]

# %%
def transform_event_roster(event):
    final_event = dict()
    final_event["type"] = "message"
    columns = ["participant", "updateType", "name", "uri", "state", "direction", "movedParticipant",
              "movedParticipantCallBridge", "canMove", "audioMuted", "videoMuted", "importance", "layout", 
              "activeSpeaker", "presenter", "endpointRecording"]
    update = dict()
    for column in columns:
        value = get_value(column, event)
        if value:
            update[column] = value
    final_event["message"] = {
        "messageId": 1,
        "type": "rosterUpdate",
        "subscriptionIndex": 1,
        "updates": [update]
    }
    final_event["date"] = event["date"]
    final_event["call"] = event["call"]
    return final_event

# %%
mapped = list(map(transform_event_roster, final.to_dict("records")))

# %%
mapped

# %%
write_json(mapped, 'roster_data.json')
